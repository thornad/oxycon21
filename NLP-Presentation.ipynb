# %%
import pandas as pd
import numpy as np
import re
#from util import *
desired_width=320
pd.set_option('display.width', desired_width)
np.set_printoptions(linewidth=desired_width)
pd.set_option('display.max_columns',20)
pd.set_option('display.max_rows', 500)

# %%
# Load language model
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
# Our example text
text="Sold in packets of 20 small pieces of 100g each"

# %%
# Convert to parsed NLP object (apply NLP pipeline)
doc=nlp(text)

# %%
# List tokens and POS
for token in doc:
    print(token.text, token.pos_)
# Out:
# Sold VERB
# in ADP
# packets NOUN
# of ADP
# 20 NUM
# small ADJ
# pieces NOUN
# of ADP
# 100 NUM
# g NOUN
# each DET

# %%
# List dependencies
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Sold sell VERB VBN ROOT Xxxx True False
# in in ADP IN prep xx True True
# packets packet NOUN NNS pobj xxxx True False
# of of ADP IN prep xx True True
# 20 20 NUM CD nummod dd False False
# small small ADJ JJ amod xxxx True False
# pieces piece NOUN NNS pobj xxxx True False
# of of ADP IN prep xx True True
# 100 100 NUM CD nummod ddd False False
# g g NOUN NN pobj x True False
# each each DET DT dobj xxxx True True

# %%
# Display dependencies
from spacy import displacy
displacy.render(doc, style="dep",options = {"compact": False, "distance": 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="de4e7fff79934d6a9c3286823fd5a05d-0" class="displacy" width="1040" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Sold</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">packets</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">20</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">small</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">pieces</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">100</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">g</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">each</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-de4e7fff79934d6a9c3286823fd5a05d-0-0" stroke-width="2px" d="M70,182.0 C70,137.0 125.0,137.0 125.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-de4e7fff79934d6a9c3286823fd5a05d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M125.0,184.0 L133.0,172.0 117.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-de4e7fff79934d6a9c3286823fd5a05d-0-1" stroke-width="2px" d="M160,182.0 C160,137.0 215.0,137.0 215.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-de4e7fff79934d6a9c3286823fd5a05d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M215.0,184.0 L223.0,172.0 207.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-de4e7fff79934d6a9c3286823fd5a05d-0-2" stroke-width="2px" d="M250,182.0 C250,137.0 305.0,137.0 305.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-de4e7fff79934d6a9c3286823fd5a05d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M305.0,184.0 L313.0,172.0 297.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-de4e7fff79934d6a9c3286823fd5a05d-0-3" stroke-width="2px" d="M430,182.0 C430,92.0 580.0,92.0 580.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-de4e7fff79934d6a9c3286823fd5a05d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,184.0 L422,172.0 438,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-de4e7fff79934d6a9c3286823fd5a05d-0-4" stroke-width="2px" d="M520,182.0 C520,137.0 575.0,137.0 575.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-de4e7fff79934d6a9c3286823fd5a05d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M520,184.0 L512,172.0 528,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-de4e7fff79934d6a9c3286823fd5a05d-0-5" stroke-width="2px" d="M340,182.0 C340,47.0 585.0,47.0 585.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-de4e7fff79934d6a9c3286823fd5a05d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M585.0,184.0 L593.0,172.0 577.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-de4e7fff79934d6a9c3286823fd5a05d-0-6" stroke-width="2px" d="M610,182.0 C610,137.0 665.0,137.0 665.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-de4e7fff79934d6a9c3286823fd5a05d-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M665.0,184.0 L673.0,172.0 657.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-de4e7fff79934d6a9c3286823fd5a05d-0-7" stroke-width="2px" d="M790,182.0 C790,137.0 845.0,137.0 845.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-de4e7fff79934d6a9c3286823fd5a05d-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M790,184.0 L782,172.0 798,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-de4e7fff79934d6a9c3286823fd5a05d-0-8" stroke-width="2px" d="M700,182.0 C700,92.0 850.0,92.0 850.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-

# %%
for token in doc:
    if token.is_digit:
        print(token, token.head)
# Out:
# 20 pieces
# 100 g

# %%
#text='NiQuitin Clear Patch Step 2, 14mg. 7 Patches Stop Smoking Aid.'
text='PG tips Original 80 Tea Bags 232g'
doc=nlp(text)
for token in doc:
    if token.is_digit:
        print(token, token.head)
# Out:
# 80 Bags
# 232 g

# %%
text='Tomatoes 5 per pack, 23.8p each. Baby spinach 160g, 62.5p per 100g. '
doc=nlp(text)
for token in doc:
    if token.is_digit:
        print(token, token.head)
# Out:
# 5 Tomatoes
# 160 g
# 100 g.

# %%
# Rule-based Matcher

# %%
from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

pattern = [{"LIKE_NUM": True},{"LOWER": "per"}, {"IS_ASCII": True}]
matcher.add("units_per_item", [pattern])

matches = matcher(doc)
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    span = doc[start:end]  # The matched span
    print(string_id+':   "'+span.text+'"')
# Out:
# units_per_item:   "5 per pack"

# %%
doc=nlp("Pack size: 170G , pack Size 100mg")
matcher = Matcher(nlp.vocab)
pattern = [{"LOWER": "pack"},{"LOWER": "size"}, 
           {"IS_PUNCT": True, "OP": "?"},
           {"LIKE_NUM": True},
           {"LOWER": {"IN": ["g", "mg"]}}]
matcher.add("pack_size", [pattern])

matches = matcher(doc)
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    span = doc[start:end]  # The matched span
    print(string_id+':   "'+span.text+'"')
    
displacy.render(doc, style="dep",options = {"compact": False, "distance": 90})
# Out:
# pack_size:   "Pack size: 170G"
# pack_size:   "pack Size 100mg"
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8ac143b0076d4af295c5b9131e882778-0" class="displacy" width="770" height="272.0" direction="ltr" style="max-width: none; height: 272.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Pack</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">size:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">170</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">G ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">pack</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Size</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">100</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">mg</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8ac143b0076d4af295c5b9131e882778-0-0" stroke-width="2px" d="M70,137.0 C70,92.0 130.0,92.0 130.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8ac143b0076d4af295c5b9131e882778-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,139.0 L62,127.0 78,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8ac143b0076d4af295c5b9131e882778-0-1" stroke-width="2px" d="M250,137.0 C250,92.0 310.0,92.0 310.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8ac143b0076d4af295c5b9131e882778-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250,139.0 L242,127.0 258,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8ac143b0076d4af295c5b9131e882778-0-2" stroke-width="2px" d="M160,137.0 C160,47.0 315.0,47.0 315.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8ac143b0076d4af295c5b9131e882778-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M315.0,139.0 L323.0,127.0 307.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8ac143b0076d4af295c5b9131e882778-0-3" stroke-width="2px" d="M430,137.0 C430,92.0 490.0,92.0 490.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8ac143b0076d4af295c5b9131e882778-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,139.0 L422,127.0 438,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8ac143b0076d4af295c5b9131e882778-0-4" stroke-width="2px" d="M340,137.0 C340,47.0 495.0,47.0 495.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8ac143b0076d4af295c5b9131e882778-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M495.0,139.0 L503.0,127.0 487.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8ac143b0076d4af295c5b9131e882778-0-5" stroke-width="2px" d="M610,137.0 C610,92.0 670.0,92.0 670.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8ac143b0076d4af295c5b9131e882778-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M610,139.0 L602,127.0 618,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8ac143b0076d4af295c5b9131e882778-0-6" stroke-width="2px" d="M160,137.0 C160,2.0 680.0,2.0 680.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8ac143b0076d4af295c5b9131e882778-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M680.0,139.0 L688.0,127.0 672.0,127.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
# Dependency Matcher

# %%
from spacy.matcher import DependencyMatcher
matcher = DependencyMatcher(nlp.vocab)

pattern = [
    {
        "RIGHT_ID": "anchor_founded",
        "RIGHT_ATTRS": {"ORTH": "founded"}
    },
    {
        "LEFT_ID": "anchor_founded",
        "REL_OP": ">",
        "RIGHT_ID": "founded_subject",
        "RIGHT_ATTRS": {"DEP": "nsubj"},
    },
    {
        "LEFT_ID": "anchor_founded",
        "REL_OP": ">",
        "RIGHT_ID": "founded_object",
        "RIGHT_ATTRS": {"DEP": "dobj"},
    },
    {
        "LEFT_ID": "founded_object",
        "REL_OP": ">",
        "RIGHT_ID": "founded_object_modifier",
        "RIGHT_ATTRS": {"DEP": {"IN": ["amod", "compound"]}},
    }
]
matcher.add("FOUNDED", [pattern])

doc=nlp("John, a friend of mine, founded two AI startups.")
displacy.render(doc, style="dep",options = {"compact": False, "distance": 90})

matches = matcher(doc)
match_id, token_ids = matches[0]
for i in range(len(token_ids)):
    print(pattern[i]["RIGHT_ID"] + ":", doc[token_ids[i]].text)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a5c9aa915c0d48338af123b4261543b4-0" class="displacy" width="860" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">John,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">friend</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">mine,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">founded</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">AI</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">startups.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a5c9aa915c0d48338af123b4261543b4-0-0" stroke-width="2px" d="M70,182.0 C70,2.0 500.0,2.0 500.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a5c9aa915c0d48338af123b4261543b4-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a5c9aa915c0d48338af123b4261543b4-0-1" stroke-width="2px" d="M160,182.0 C160,137.0 215.0,137.0 215.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a5c9aa915c0d48338af123b4261543b4-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M160,184.0 L152,172.0 168,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a5c9aa915c0d48338af123b4261543b4-0-2" stroke-width="2px" d="M70,182.0 C70,92.0 220.0,92.0 220.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a5c9aa915c0d48338af123b4261543b4-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220.0,184.0 L228.0,172.0 212.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a5c9aa915c0d48338af123b4261543b4-0-3" stroke-width="2px" d="M250,182.0 C250,137.0 305.0,137.0 305.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a5c9aa915c0d48338af123b4261543b4-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M305.0,184.0 L313.0,172.0 297.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a5c9aa915c0d48338af123b4261543b4-0-4" stroke-width="2px" d="M340,182.0 C340,137.0 395.0,137.0 395.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a5c9aa915c0d48338af123b4261543b4-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,184.0 L403.0,172.0 387.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a5c9aa915c0d48338af123b4261543b4-0-5" stroke-width="2px" d="M610,182.0 C610,92.0 760.0,92.0 760.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a5c9aa915c0d48338af123b4261543b4-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M610,184.0 L602,172.0 618,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a5c9aa915c0d48338af123b4261543b4-0-6" stroke-width="2px" d="M700,182.0 C700,137.0 755.0,137.0 755.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a5c9aa915c0d48338af123b4261543b4-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M700,184.0 L692,172.0 708,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a5c9aa915c0d48338af123b4261543b4-0-7" stroke-width="2px" d="M520,182.0 C520,47.0 765.0,47.0 765.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a5c9aa915c0d48338af123b4261543b4-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M765.0,184.0 L773.0,172.0 757.0,172.0" fill="currentColor"/>
# </g>
# </svg></span>
# anchor_founded: founded
# founded_subject: John
# founded_object: startups
# founded_object_modifier: AI

# %%
import spacy
from spacy.matcher import DependencyMatcher

nlp.add_pipe("merge_entities")# merge entities to simplify this


pattern = [
        {
            "RIGHT_ID": "person",
            "RIGHT_ATTRS": {"ENT_TYPE": "PERSON", "DEP": "nsubj"},
        },
        {
            "LEFT_ID": "person",
            "REL_OP": "<",
            "RIGHT_ID": "verb",
            "RIGHT_ATTRS": {"POS": "VERB"},
        }]

matcher = DependencyMatcher(nlp.vocab)
matcher.add("WHO_DID_WHAT", [pattern])

texts = [
        "Steve Jobs founded Apple when he was young.",
        "Mike, a friend of mine, wrote a book."
        '"Hello!", says Mary.',
        ]

for text in texts:
    doc = nlp(text)
    matches = matcher(doc)

    for match in matches:
        match_id, (start, end) = match
        print(doc[start], "::", doc[end])
# Out:
# Steve Jobs :: founded
# Mike :: wrote
# Mary :: says

# %%
# NER - Named Entity Recognition

# %%
doc=nlp("Everlearn Ltd founded by John McAfee partenered with Apple to provide education "
    "in the Middle East, North Africa, Asia Pacific, South Asia, and the Americas."
    "It believes that education is purpose-driven. That’s why it empowers children "
    "and adults to be creative, innovative, entrepreneurial, and disruptive.")
for entity in doc.ents:
      print(entity.label_, ' | ', entity.text)
displacy.render(doc, style="ent")
# Out:
# ORG  |  Everlearn Ltd
# PERSON  |  John McAfee
# ORG  |  Apple
# LOC  |  the Middle East
# GPE  |  North Africa
# LOC  |  Asia Pacific
# LOC  |  South Asia
# LOC  |  Americas
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Everlearn Ltd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  founded by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John McAfee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  partenered with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to provide education in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Middle East
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North Africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Asia Pacific
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     South Asia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , and the
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .It believes that education is purpose-driven. That’s why it empowers children and adults to be creative, innovative, entrepreneurial, and disruptive.</div></span>

# %%
doc=nlp('''The Slim Fit MVP is a slim fitting, ultra comfortable classic Jeans. The Extreme Motion series are the ultimate combination between extreme comfort, freedom to move and authentic denim, coming here in a slim fit execution.
Featuring the amazing comfort, movement and unbeatable stretch of Lee’s Extreme Motion collection, these slim fit jeans are made with motion in mind. Look for the grey elastic in the super comfy athletic waistband and the signature donut button and brown leather back patch. Made using recycled fabric and constructed using a cleverly tapered slim fit.''')
for entity in doc.ents:
      print(entity.label_, ' | ', entity.text)
displacy.render(doc, style="ent")
# Out:
# ORG  |  Slim Fit MVP
# NORP  |  Jeans
# PERSON  |  Lee
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Slim Fit MVP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a slim fitting, ultra comfortable classic
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jeans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# . The Extreme Motion series are the ultimate combination between extreme comfort, freedom to move and authentic denim, coming here in a slim fit execution.</br>Featuring the amazing comfort, movement and unbeatable stretch of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s Extreme Motion collection, these slim fit jeans are made with motion in mind. Look for the grey elastic in the super comfy athletic waistband and the signature donut button and brown leather back patch. Made using recycled fabric and constructed using a cleverly tapered slim fit.</div></span>

# %%
brands=pd.read_csv("brands.csv")
jeans=pd.read_csv("jeans.csv")["name"]

# %%
# Customize NER Pipeline

# %%
# training data
TRAIN_DATA = [( jeans[x] , {"entities": [(0,len(jeans[x].split(" ")[0] ), "BRAND")]}) 
              for x in jeans.index]
TRAIN_DATA
# Out:
# [('Wrangler Regular Stretch Jeans - Navy', {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Regular Stretch Jeans - Camel', {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Regular Stretch Jeans - Stonewash',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Regular Stretch Jeans - Darkstone',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Regular Stretch Jeans - Black', {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Regular Stretch Jeans - Rinsewash',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Lee Slim Fit Jeans - Lenny', {'entities': [(0, 3, 'BRAND')]}),
#  ('Lee Slim Chino Trousers - Taupe', {'entities': [(0, 3, 'BRAND')]}),
#  ('Lee Slim Chino Trousers - Navy', {'entities': [(0, 3, 'BRAND')]}),
#  ('Lee Slim Chino Trousers - Dark Grey', {'entities': [(0, 3, 'BRAND')]}),
#  ('Lee Slim Fit Jeans - Rinse', {'entities': [(0, 3, 'BRAND')]}),
#  ('Lee Slim Fit Jeans - Aristocrat', {'entities': [(0, 3, 'BRAND')]}),
#  ('Lee Regular Straight Fit Jeans - Black', {'entities': [(0, 3, 'BRAND')]}),
#  ('Lee Regular Straight Fit Jeans - Cougar', {'entities': [(0, 3, 'BRAND')]}),
#  ('Lee Regular Straight Fit Jeans - Trip', {'entities': [(0, 3, 'BRAND')]}),
#  ('Lee Regular Straight Fit Jeans - Maddox', {'entities': [(0, 3, 'BRAND')]}),
#  ('Columbia Triple Canyon Trousers - Black', {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Texas Regular Jeans - Darkstone', {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Texas Stretch Regular Jeans - Worn Broke',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Texas Stretch Regular Jeans - Blue Black',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Texas Regular Jeans - Blue Black',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Texas Stretch Regular Jeans - Like a Champ',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Texas Stretch Regular Jeans - Comfort Zone',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Texas Stretch Regular Jeans - Darkstone',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Texas Stretch Regular Jeans - Black Overdye',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Texas Stretch Regular Jeans - Stonewash',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Texas Stretch Regular Jeans - Vintage Tint',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Texas Regular Jeans - Stonewash', {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Texas Slim High Stretch Jeans - Black Valley',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Texas Slim Low Stretch Jeans - Game On',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Texas Slim Medium Stretch Jeans - Dark Rinse',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Larston Slim Tapered Medium Stretch Jeans - Dark Rinse',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Dockers Alpha Original Skinny Khakis - New British Khaki',
#   {'entities': [(0, 7, 'BRAND')]}),
#  ('Dockers Alpha Original Skinny Khakis - Burma Grey',
#   {'entities': [(0, 7, 'BRAND')]}),
#  ('Dockers Alpha Original Slim Tapered Khakis - Pembroke',
#   {'entities': [(0, 7, 'BRAND')]}),
#  ('Dockers Alpha Original Slim Tapered Khakis - New British Khaki',
#   {'entities': [(0, 7, 'BRAND')]}),
#  ('Dockers Alpha Original Slim Tapered Khakis - Olive',
#   {'entities': [(0, 7, 'BRAND')]}),
#  ('Dockers Alpha Original Slim Tapered Khakis - Safari Beige',
#   {'entities': [(0, 7, 'BRAND')]}),
#  ('Dockers Alpha Original Slim Tapered Khakis - Black',
#   {'entities': [(0, 7, 'BRAND')]}),
#  ('Dockers Alpha Original Slim Tapered Khakis - Dark Pebble',
#   {'entities': [(0, 7, 'BRAND')]}),
#  ('Dickies 873 Slim Straight Fit Work Trousers - Charcoal Grey',
#   {'entities': [(0, 7, 'BRAND')]}),
#  ('Dickies 874 Original Work Trousers - Black',
#   {'entities': [(0, 7, 'BRAND')]}),
#  ('Dickies 873 Slim Straight Fit Work Trousers - Black',
#   {'entities': [(0, 7, 'BRAND')]}),
#  ('Dickies 872 Slim Fit Work Trousers - Black',
#   {'entities': [(0, 7, 'BRAND')]}),
#  ('Guess Angel Duks Slim Fit Denim Jeans - Dukes',
#   {'entities': [(0, 5, 'BRAND')]}),
#  ('Dickies Fairdale Twill Trousers - Black', {'entities': [(0, 7, 'BRAND')]}),
#  ('Wrangler Greensboro Regular Straight Fit Low Stretch Jeans - Darkstone',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Greensboro Regular Straight Fit Low Stretch Jeans - Black Valley',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Larston Slim Tapered Low Stretch Jeans - Black Valley',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Lee Brooklyn Straight Jeans - Dark Stone', {'entities': [(0, 3, 'BRAND')]}),
#  ('Lee Luke Slim Tapered Low Stretch Jeans - Rinse',
#   {'entities': [(0, 3, 'BRAND')]}),
#  ('Wrangler Arizona Straight Leg Slight Stretch Jeans - Black Valley',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Texas Slim Medium Stretch Jeans - Lucky Star',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Arizona Straight Leg Slight Stretch Jeans - Burnt Blue',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Lee Luke Slim Tapered Low Stretch Jeans - Clean Black',
#   {'entities': [(0, 3, 'BRAND')]}),
#  ('Dockers Smart 360 Flex Alpha Skinny Fit Khakis - Pembroke',
#   {'entities': [(0, 7, 'BRAND')]}),
#  ('Wrangler Bryson Skinny Jeans - Game On', {'entities': [(0, 8, 'BRAND')]}),
#  ("Levi's 501 Regular Fit Jeans - Onewash", {'entities': [(0, 6, 'BRAND')]}),
#  ('Dockers Smart 360 Flex Alpha Skinny Fit Khakis - Black',
#   {'entities': [(0, 7, 'BRAND')]}),
#  ('Lee Malone Skinny Jeans - Black Rinse', {'entities': [(0, 3, 'BRAND')]}),
#  ('Wrangler Bryson Skinny Jeans - Blackopedia',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ("Levi's 501 Regular Fit Jeans - Stonewash", {'entities': [(0, 6, 'BRAND')]}),
#  ('Wrangler Greensboro Regular Straight Fit Medium Stretch Jeans - Bright Stroke',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Lee Brooklyn Straight Jeans - Mid Stonewash',
#   {'entities': [(0, 3, 'BRAND')]}),
#  ('Lee Brooklyn Straight Jeans - Blue Black', {'entities': [(0, 3, 'BRAND')]}),
#  ('Lee Brooklyn Straight Jeans - Rinse', {'entities': [(0, 3, 'BRAND')]}),
#  ("Levi's 501 Regular Fit Jeans - Black", {'entities': [(0, 6, 'BRAND')]}),
#  ("Levi's 501 Regular Fit Jeans - Marlon", {'entities': [(0, 6, 'BRAND')]}),
#  ('Wrangler Larston Slim Tapered Medium Stretch Jeans - Blue Fever',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Wrangler Larston Slim Tapered Low Stretch Jeans - Blue Fire',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Lee Brooklyn Straight Jeans - Clean Black',
#   {'entities': [(0, 3, 'BRAND')]}),
#  ("Levi's 514 Straight Jeans - Stonewash Stretch",
#   {'entities': [(0, 6, 'BRAND')]}),
#  ("Levi's 514 Straight Jeans - Chain Rinse", {'entities': [(0, 6, 'BRAND')]}),
#  ('Lee Malone Skinny Jeans - Blue Drop', {'entities': [(0, 3, 'BRAND')]}),
#  ('Lee Luke Slim Tapered Low Stretch Jeans - Fresh',
#   {'entities': [(0, 3, 'BRAND')]}),
#  ('Wrangler Greensboro Regular Straight Fit Low Stretch Jeans - El Camino',
#   {'entities': [(0, 8, 'BRAND')]}),
#  ('Lee Luke Slim Tapered Low Stretch Jeans - True Authentic',
#   {'entities': [(0, 3, 'BRAND')]}),
#  ('Diesel Larkee Regular Jeans - Dark Blue (009HF)',
#   {'entities': [(0, 6, 'BRAND')]}),
#  ('Diesel Larkee Regular Jeans - Black (0688H)',
#   {'entities': [(0, 6, 'BRAND')]}),
#  ('Diesel Waykee Regular Fit Stretch Jeans - Dark Blue (0814W)',
#   {'entities': [(0, 6, 'BRAND')]}),
#  ('Diesel D-Luster Slim Jeans – Dark Blue (009NN)',
#   {'entities': [(0, 6, 'BRAND')]}),
#  ("Levi's 512 Slim Tapered Jeans - Pelican Rust",
#   {'entities': [(0, 6, 'BRAND')]}),
#  ("Levi's 502 Regular Tapered Jeans - Wagyu Moss",
#   {'entities': [(0, 6, 'BRAND')]}),
#  ("Levi's 502 Regular Tapered Jeans - Now And Never",
#   {'entities': [(0, 6, 'BRAND')]}),
#  ('Diesel D-Fining Tapered Jeans - Black (0688H)',
#   {'entities': [(0, 6, 'BRAND')]}),
#  ('Diesel Sleenker Skinny Jeans - Black (069EI)',
#   {'entities': [(0, 6, 'BRAND')]}),
#  ("Levi's 502 Regular Tapered Jeans - Moto Cross",
#   {'entities': [(0, 6, 'BRAND')]}),
#  ("Levi's 511 Slim Jeans - Poncho", {'entities': [(0, 6, 'BRAND')]}),
#  ("Levi's 502 Regular Tapered Jeans - Rock Cod",
#   {'entities': [(0, 6, 'BRAND')]}),
#  ("Levi's 512 Slim Tapered Jeans - Rock Cod", {'entities': [(0, 6, 'BRAND')]}),
#  ("Levi's 502 Regular Tapered Jeans - Nightshine",
#   {'entities': [(0, 6, 'BRAND')]}),
#  ("Levi's 511 Slim Jeans - Rock Cod", {'entities': [(0, 6, 'BRAND')]}),
#  ("Levi's 512 Slim Tapered Jeans - Nightshine",
#   {'entities': [(0, 6, 'BRAND')]}),
#  ('Diesel Larkee Regular Jeans - Medium Blue (009EI)',
#   {'entities': [(0, 6, 'BRAND')]}),
#  ("Levi's 511 Slim Jeans - Fennel Subtle", {'entities': [(0, 6, 'BRAND')]}),
#  ("Levi's 512 Slim Tapered Jeans - Whoop", {'entities': [(0, 6, 'BRAND')]}),
#  ('Diesel Zatiny Regular Bootcut Jeans - Dark Blue (009HN)',
#   {'entities': [(0, 6, 'BRAND')]}),
#  ('Diesel Zatiny Regular Bootcut Jeans - Medium Blue (009EI)',
#   {'entities': [(0, 6, 'BRAND')]}),
#  ('Diesel Larkee Regular Jeans - Dark Blue (009HN)',
#   {'entities': [(0, 6, 'BRAND')]}),
#  ('Diesel D-Fining Tapered Jeans - Dark Blue (009HF)',
#   {'entities': [(0, 6, 'BRAND')]})]

# %%
# Load pre-existing spacy model
import spacy
nlp=spacy.load('en_core_web_sm')

# Getting the pipeline component
ner=nlp.get_pipe("ner")

# New label to add
LABEL = "BRAND"

# Add the new label to ner
ner.add_label(LABEL)

# Resume training
optimizer = nlp.resume_training()
move_names = list(ner.move_names)

# List of pipes you want to train
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]

# List of pipes which should remain unaffected in training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

from spacy.util import minibatch, compounding
import random

# Begin training by disabling other pipeline components
with nlp.disable_pipes(*other_pipes) :
    sizes = compounding(1.0, 4.0, 1.001)
    # Training for 30 iterations     
    for itn in range(30):
    # shuffle examples before training
        random.shuffle(TRAIN_DATA)
        # batch up the examples using spaCy's minibatch
        batches = minibatch(TRAIN_DATA, size=sizes)
        # dictionary to store losses
        losses = {}
        for batch in batches:
            texts, annotations = zip(*batch)
            example = []
            for text, annotations in batch:
                doc = nlp.make_doc(text)
                example.append( Example.from_dict(doc, annotations))
                nlp.update(
                            example,
                            drop=0.5,  # dropout - make it harder to memorise data
                            losses=losses,
                        )
            print("Losses", losses)
# Out:
# Losses {'ner': 5.11392423446523}
# Losses {'ner': 11.284166703544088}
# Losses {'ner': 15.577562182482964}
# Losses {'ner': 20.985475509729277}
# Losses {'ner': 24.775912763713112}
# Losses {'ner': 27.037826578638832}
# Losses {'ner': 29.88866926760596}
# Losses {'ner': 31.197716305214083}
# Losses {'ner': 33.907528067655036}
# Losses {'ner': 38.96058855682331}
# Losses {'ner': 42.21106432715919}
# Losses {'ner': 44.226306199782925}
# Losses {'ner': 46.230815022510406}
# Losses {'ner': 48.28720327172375}
# Losses {'ner': 51.58097155998036}
# Losses {'ner': 53.906150667593074}
# Losses {'ner': 57.15503844348452}
# Losses {'ner': 59.14233595885899}
# Losses {'ner': 60.77487931126403}
# Losses {'ner': 62.05314719549111}
# Losses {'ner': 65.58124440559382}
# Losses {'ner': 67.47993823359755}
# Losses {'ner': 69.06064645000177}
# Losses {'ner': 71.84102051232841}
# Losses {'ner': 73.52141319237273}
# Losses {'ner': 76.41343262914017}
# Losses {'ner': 78.50669938305788}
# Losses {'ner': 79.89221081086822}
# Losses {'ner': 81.35532910706382}
# Losses {'ner': 82.99276591209582}
# Losses {'ner': 85.08936525396908}
# Losses {'ner': 86.80909122239896}
# Losses {'ner': 88.43424828048924}
# Losses {'ner': 90.22644130731365}
# Losses {'ner': 91.39202870003388}
# Losses {'ner': 93.6538172073098}
# Losses {'ner': 95.06304720331943}
# Losses {'ner': 97.26176380691386}
# Losses {'ner': 99.34361857563279}
# Losses {'ner': 101.35543664698976}
# Losses {'ner': 103.22001638747902}
# Losses {'ner': 104.37495659616475}
# Losses {'ner': 105.32947156084488}
# Losses {'ner': 107.05054231370964}
# Losses {'ner': 108.98082027839764}
# Losses {'ner': 111.1192882370785}
# Losses {'ner': 111.81808901172947}
# Losses {'ner': 112.7100880570459}
# Losses {'ner': 113.8478018028821}
# Losses {'ner': 115.48976113837018}
# Losses {'ner': 116.32919960546026}
# Losses {'ner': 117.66949982095578}
# Losses {'ner': 118.97065436933083}
# Losses {'ner': 120.1396331406457}
# Losses {'ner': 121.9911221512037}
# Losses {'ner': 133.34010967862815}
# Losses {'ner': 135.08156824260624}
# Losses {'ner': 136.85193759337818}
# Losses {'ner': 138.09828334861487}
# Losses {'ner': 138.58677865970714}
# Losses {'ner': 140.1744164983018}
# Losses {'ner': 142.81442273901376}
# Losses {'ner': 143.86962127916814}
# Losses {'ner': 144.39554060506163}
# Losses {'ner': 145.17064442357042}
# Losses {'ner': 146.5817986320788}
# Losses {'ner': 147.9718150025936}
# Losses {'ner': 149.3421951815024}
# Losses {'ner': 149.6138853095061}
# Losses {'ner': 150.09006793863483}
# Losses {'ner': 151.62461078227653}
# Losses {'ner': 151.71785735485724}
# Losses {'ner': 152.4146378438066}
# Losses {'ner': 153.53342147315414}
# Losses {'ner': 154.02950005332093}
# Losses {'ner': 155.00690012748817}
# Losses {'ner': 155.3650759380889}
# Losses {'ner': 155.4875650425001}
# Losses {'ner': 155.57762756873532}
# Losses {'ner': 155.6225299352832}
# Losses {'ner': 157.47516156027953}
# Losses {'ner': 157.88074485029998}
# Losses {'ner': 157.89960910899723}
# Losses {'ner': 157.96527461768872}
# Losses {'ner': 158.2211503592264}
# Losses {'ner': 158.57627863156372}
# Losses {'ner': 158.69617696154444}
# Losses {'ner': 159.99545308121645}
# Losses {'ner': 161.77998385206064}
# Losses {'ner': 161.78115607940802}
# Losses {'ner': 161.78296397221308}
# Losses {'ner': 161.7992050823416}
# Losses {'ner': 161.81742559983996}
# Losses {'ner': 161.8332878033464}
# Losses {'ner': 163.6097405705439}
# Losses {'ner': 165.01897806114192}
# Losses {'ner': 166.05669105970813}
# Losses {'ner': 166.0627516128375}
# Losses {'ner': 166.06401052740202}
# Losses {'ner': 167.58711633758278}
# Losses {'ner': 0.10093258086513157}
# Losses {'ner': 1.2344345290501635}
# Losses {'ner': 1.7056838342235014}
# Losses {'ner': 2.3756066823432573}
# Losses {'ner': 2.4253169270116706}
# Losses {'ner': 2.4794110123074793}
# Losses {'ner': 4.760822473000396}
# Losses {'ner': 6.111140225640159}
# Losses {'ner': 6.111411865114752}
# Losses {'ner': 7.644241813806571}
# Losses {'ner': 8.061075253612108}
# Losses {'ner': 8.062233867453445}
# Losses {'ner': 9.636516182947512}
# Losses {'ner': 10.610389487925135}
# Losses {'ner': 10.612211438178381}
# Losses {'ner': 10.612356749160801}
# Losses {'ner': 11.727291979793284}
# Losses {'ner': 13.82401851336167}
# Losses {'ner': 14.777673763065916}
# Losses {'ner': 15.999387468033822}
# Losses {'ner': 16.366962891511907}
# Losses {'ner': 16.371010750897437}
# Losses {'ner': 16.63102868721304}
# Losses {'ner': 18.220525565712176}
# Losses {'ner': 18.22446709293853}
# Losses {'ner': 18.224840136074352}
# Losses {'ner': 18.268546007540447}
# Losses {'ner': 19.021503131685936}
# Losses {'ner': 19.46789697649256}
# Losses {'ner': 19.579763803493126}
# Losses {'ner': 19.579833864984334}
# Losses {'ner': 19.600420806895432}
# Losses {'ner': 19.65799591142348}
# Losses {'ner': 21.56063993289248}
# Losses {'ner': 22.66609165110019}
# Losses {'ner': 22.692699676112255}
# Losses {'ner': 31.204959099845013}
# Losses {'ner': 31.474333843341334}
# Losses {'ner': 39.57299282228039}
# Losses {'ner': 39.57302230510797}
# Losses {'ner': 39.582385258636705}
# Losses {'ner': 39.58659186569796}
# Losses {'ner': 39.58761647973062}
# Losses {'ner': 39.596774797032886}
# Losses {'ner': 39.60657865723597}
# Losses {'ner': 43.34580550461151}
# Losses {'ner': 43.345818347483664}
# Losses {'ner': 43.34591465571359}
# Losses {'ner': 43.35405064347913}
# Losses {'ner': 43.354059009989584}
# Losses {'ner': 43.35405932185637}
# Losses {'ner': 43.354080542588186}
# Losses {'ner': 43.354080554835214}
# Losses {'ner': 43.354083884419616}
# Losses {'ner': 43.35411075318105}
# Losses {'ner': 43.35417366934994}
# Losses {'ner': 43.77671067313847}
# Losses {'ner': 43.77673272244876}
# Losses {'ner': 44.392584919224646}
# Losses {'ner': 44.39258542041038}
# Losses {'ner': 44.39258670957004}
# Losses {'ner': 44.39258806374845}
# Losses {'ner': 46.46896740375091}
# Losses {'ner': 46.46920054475168}
# Losses {'ner': 46.5465995831304}
# Losses {'ner': 46.547393947544975}
# Losses {'ner': 47.964141193105455}
# Losses {'ner': 47.96420096060902}
# Losses {'ner': 47.96420096401807}
# Losses {'ner': 47.96440093851382}
# Losses {'ner': 47.964400965549785}
# Losses {'ner': 47.9644070096472}
# Losses {'ner': 47.99397643832482}
# Losses {'ner': 47.99399565752928}
# Losses {'ner': 47.993995889410606}
# Losses {'ner': 48.59452096858074}
# Losses {'ner': 48.59452212976227}
# Losses {'ner': 48.59454578620863}
# Losses {'ner': 50.04734482512865}
# Losses {'ner': 51.77750245467256}
# Losses {'ner': 52.261963115023555}
# Losses {'ner': 54.15475994541899}
# Losses {'ner': 54.154760680760866}
# Losses {'ner': 54.1552062511223}
# Losses {'ner': 54.15520625458086}
# Losses {'ner': 54.295708506800054}
# Losses {'ner': 54.29570907771131}
# Losses {'ner': 54.29570908168458}
# Losses {'ner': 56.05589364769724}
# Losses {'ner': 56.055977723539065}
# Losses {'ner': 56.081900530040016}
# Losses {'ner': 56.08220097121755}
# Losses {'ner': 56.10292537095127}
# Losses {'ner': 56.102948128024146}
# Losses {'ner': 57.55327035358166}
# Losses {'ner': 57.553274674473705}
# Losses {'ner': 57.594608001093654}
# Losses {'ner': 57.59460852190536}
# Losses {'ner': 57.61516771224788}
# Losses {'ner': 57.61569283850943}
# Losses {'ner': 1.2986076016530335e-06}
# Losses {'ner': 1.9473161261717883e-06}
# Losses {'ner': 2.5368208768088143e-06}
# Losses {'ner': 2.538272119328539e-06}
# Losses {'ner': 0.0003614783811539925}
# Losses {'ner': 0.0003645581616174255}
# Losses {'ner': 0.00036488216346471265}
# Losses {'ner': 0.6993065880058872}
# Losses {'ner': 0.7321871896631462}
# Losses {'ner': 0.7576295003536638}
# Losses {'ner': 0.75762983853294}
# Losses {'ner': 0.8424066453470836}
# Losses {'ner': 0.8719986117679274}
# Losses {'ner': 0.8719986136379966}
# Losses {'ner': 0.8720215338900983}
# Losses {'ner': 0.8721329473947848}
# Losses {'ner': 2.3262845777967445}
# Losses {'ner': 2.326284604792049}
# Losses {'ner': 2.4165369297537707}
# Losses {'ner': 2.417131277789762}
# Losses {'ner': 4.033908687098929}
# Losses {'ner': 4.099172085098906}
# Losses {'ner': 4.102998489526113}
# Losses {'ner': 4.106108380167963}
# Losses {'ner': 4.106268593381442}
# Losses {'ner': 5.4599422956500945}
# Losses {'ner': 5.459942297836909}
# Losses {'ner': 5.459943899601405}
# Losses {'ner': 5.498958131016109}
# Losses {'ner': 5.498959812110554}
# Losses {'ner': 5.498960091563944}
# Losses {'ner': 5.6425097513873785}
# Losses {'ner': 5.642542674781945}
# Losses {'ner': 5.642542692137261}
# Losses {'ner': 5.642542763437713}
# Losses {'ner': 5.8985910493567655}
# Losses {'ner': 5.89859107352305}
# Losses {'ner': 5.97786002636491}
# Losses {'ner': 5.977860034979231}
# Losses {'ner': 5.977860051467269}
# Losses {'ner': 5.977868421297424}
# Losses {'ner': 5.9778685319755285}
# Losses {'ner': 5.977870538716942}
# Losses {'ner': 5.979878282812038}
# Losses {'ner': 5.979880355342997}
# Losses {'ner': 5.979880355556712}
# Losses {'ner': 5.98044567393596}
# Losses {'ner': 5.980445675336233}
# Losses {'ner': 5.983938235336498}
# Losses {'ner': 5.9839398667025465}
# Losses {'ner': 5.983939867165603}
# Losses {'ner': 5.986154897461626}
# Losses {'ner': 5.986176233880633}
# Losses {'ner': 5.986180789775023}
# Losses {'ner': 5.9861829265566735}
# Losses {'ner': 5.986183230000613}
# Losses {'ner': 6.002320695950955}
# Losses {'ner': 6.002320731830611}
# Losses {'ner': 6.002320737674327}
# Losses {'ner': 6.002320737951711}
# Losses {'ner': 6.00232073832039}
# Losses {'ner': 6.002357678638633}
# Losses {'ner': 6.002357777217415}
# Losses {'ner': 6.002357939291211}
# Losses {'ner': 6.0023586821446875}
# Losses {'ner': 6.00236904602452}
# Losses {'ner': 6.002377450153758}
# Losses {'ner': 6.002377452559527}
# Losses {'ner': 6.614007802923502}
# Losses {'ner': 6.6142188607443355}
# Losses {'ner': 6.61421886075104}
# Losses {'ner': 6.614218861643423}
# Losses {'ner': 6.6142207995410285}
# Losses {'ner': 6.6270340653524}
# Losses {'ner': 6.627038396432668}
# Losses {'ner': 6.627039075475627}
# Losses {'ner': 6.627039081203062}
# Losses {'ner': 6.627041512813255}
# Losses {'ner': 6.6270421486511975}
# Losses {'ner': 6.647721166489735}
# Losses {'ner': 6.647721260426728}
# Losses {'ner': 6.649722663703476}
# Losses {'ner': 6.649724134828597}
# Losses {'ner': 6.6497241383982475}
# Losses {'ner': 6.649737933768761}
# Losses {'ner': 6.649737933914596}
# Losses {'ner': 6.649737940212991}
# Losses {'ner': 6.649737956211695}
# Losses {'ner': 6.650245391182731}
# Losses {'ner': 6.650245392606343}
# Losses {'ner': 6.6502453935531625}
# Losses {'ner': 6.650245412558418}
# Losses {'ner': 6.650245424040013}
# Losses {'ner': 6.650246062017378}
# Losses {'ner': 6.650246339379978}
# Losses {'ner': 6.650246607465586}
# Losses {'ner': 6.650313921224879}
# Losses {'ner': 6.650315096875064}
# Losses {'ner': 6.6503282135248}
# Losses {'ner': 6.650328409785522}
# Losses {'ner': 0.0034323276058184082}
# Losses {'ner': 0.003432329067495678}
# Losses {'ner': 0.0034323291203523405}
# Losses {'ner': 0.05125970059526493}
# Losses {'ner': 0.051259700595577475}
# Losses {'ner': 0.05126103227588719}
# Losses {'ner': 0.05126103228905328}
# Losses {'ner': 0.051262316118805856}
# Losses {'ner': 0.051262322289871265}
# Losses {'ner': 0.05126232721001976}
# Losses {'ner': 0.051262329135451985}
# Losses {'ner': 0.05162846578012424}
# Losses {'ner': 0.051628467410772975}
# Losses {'ner': 0.05169272993388384}
# Losses {'ner': 0.05169325047324513}
# Losses {'ner': 0.05169325062715269}
# Losses {'ner': 0.051693265268990596}
# Losses {'ner': 0.05169326532714344}
# Losses {'ner': 0.051827538354505216}
# Losses {'ner': 0.051843588497117434}
# Losses {'ner': 0.05184589499348904}
# Losses {'ner': 0.05184599258123461}
# Losses {'ner': 0.051846530651415916}
# Losses {'ner': 0.05184653084219475}
# Losses {'ner': 0.0518479618906082}
# Losses {'ner': 0.05184796873001937}
# Losses {'ner': 0.05184796901618546}
# Losses {'ner': 0.051852243502219175}
# Losses {'ner': 0.05185224531644822}
# Losses {'ner': 0.05185225033396412}
# Losses {'ner': 0.0518525411886366}
# Losses {'ner': 0.05185254127626276}
# Losses {'ner': 0.051852541279654635}
# Losses {'ner': 0.6988691352370903}
# Losses {'ner': 0.6988706120247572}
# Losses {'ner': 0.6988708181326951}
# Losses {'ner': 0.6988708201557974}
# Losses {'ner': 0.6988733638216128}
# Losses {'ner': 0.6988772294184977}
# Losses {'ner': 0.6989093488460113}
# Losses {'ner': 0.6989094255597322}
# Losses {'ner': 0.6989094282142183}
# Losses {'ner': 0.69890946797587}
# Losses {'ner': 0.6989094706684308}
# Losses {'ner': 0.698909470696073}
# Losses {'ner': 0.6989612750619875}
# Losses {'ner': 0.698961384263331}
# Losses {'ner': 0.6989613842693625}
# Losses {'ner': 0.6989613886626261}
# Losses {'ner': 2.689337623276647}
# Losses {'ner': 2.689339628659032}
# Losses {'ner': 2.6893396315613742}
# Losses {'ner': 2.689339915055761}
# Losses {'ner': 2.6893399154277797}
# Losses {'ner': 2.691119120077097}
# Losses {'ner': 2.6911196270781095}
# Losses {'ner': 2.691119706937041}
# Losses {'ner': 2.6911614826419443}
# Losses {'ner': 2.691173477974623}
# Losses {'ner': 2.6911739116154916}
# Losses {'ner': 2.6911754282299385}
# Losses {'ner': 2.6911754643790564}
# Losses {'ner': 2.6911754644023618}
# Losses {'ner': 2.6911754667472136}
# Losses {'ner': 2.6911754780115063}
# Losses {'ner': 2.691175479826124}
# Losses {'ner': 2.691175479826974}
# Losses {'ner': 2.6911754803961987}
# Losses {'ner': 2.691175480524344}
# Losses {'ner': 2.6911754805248984}
# Losses {'ner': 2.6911762339605647}
# Losses {'ner': 2.691176237047627}
# Losses {'ner': 2.6911839382096048}
# Losses {'ner': 2.6911842121739094}
# Losses {'ner': 2.691184212195358}
# Losses {'ner': 2.6911842618379005}
# Losses {'ner': 2.691184551555627}
# Losses {'ner': 2.6912843295007103}
# Losses {'ner': 2.69128433534793}
# Losses {'ner': 2.7002347847430106}
# Losses {'ner': 3.6365842731378084}
# Losses {'ner': 3.6365842751176087}
# Losses {'ner': 3.636584276599664}
# Losses {'ner': 3.636586855008157}
# Losses {'ner': 3.636587329421926}
# Losses {'ner': 3.6374059790200173}
# Losses {'ner': 3.6374059795817555}
# Losses {'ner': 3.6374070870431363}
# Losses {'ner': 3.637407087063699}
# Losses {'ner': 4.68137004316388}
# Losses {'ner': 4.681370043190243}
# Losses {'ner': 4.681370043239031}
# Losses {'ner': 4.681422379293226}
# Losses {'ner': 4.681422380992132}
# Losses {'ner': 4.681424896689685}
# Losses {'ner': 4.681424897692899}
# Losses {'ner': 4.681424970268131}
# Losses {'ner': 4.681425010646593}
# Losses {'ner': 4.681425016582749}
# Losses {'ner': 4.681425018944847}
# Losses {'ner': 1.6634479078592984e-10}
# Losses {'ner': 5.2151103229184886e-08}
# Losses {'ner': 5.216861161671225e-08}
# Losses {'ner': 6.2433920264313785e-06}
# Losses {'ner': 6.31189359795322e-06}
# Losses {'ner': 6.417203818095583e-06}
# Losses {'ner': 6.41770495678596e-06}
# Losses {'ner': 2.1300997351270252e-05}
# Losses {'ner': 2.1301292775190595e-05}
# Losses {'ner': 2.1302917134594347e-05}
# Losses {'ner': 2.1302950267161333e-05}
# Losses {'ner': 2.1305998476775385e-05}
# Losses {'ner': 2.130604080138188e-05}
# Losses {'ner': 2.1498392412855455e-05}
# Losses {'ner': 2.1498400757771925e-05}
# Losses {'ner': 2.1498894454761597e-05}
# Losses {'ner': 2.1502658330162077e-05}
# Losses {'ner': 2.150366349444399e-05}
# Losses {'ner': 2.150744091554088e-05}
# Losses {'ner': 2.155442157666254e-05}
# Losses {'ner': 2.1556163986108375e-05}
# Losses {'ner': 2.155640479827265e-05}
# Losses {'ner': 2.1557158303746482e-05}
# Losses {'ner': 2.1602574323624758e-05}
# Losses {'ner': 2.1602747713470882e-05}
# Losses {'ner': 2.1608414155075303e-05}
# Losses {'ner': 2.216166805109096e-05}
# Losses {'ner': 2.2165016292876145e-05}
# Losses {'ner': 3.025623337756365e-05}
# Losses {'ner': 3.0425908780197594e-05}
# Losses {'ner': 3.0436994848161006e-05}
# Losses {'ner': 3.043699885558366e-05}
# Losses {'ner': 3.0437981582003626e-05}
# Losses {'ner': 3.045165951554509e-05}
# Losses {'ner': 3.047023526652987e-05}
# Losses {'ner': 3.047960871307681e-05}
# Losses {'ner': 3.052663594738603e-05}
# Losses {'ner': 3.2429751057593583e-05}
# Losses {'ner': 3.243255751912079e-05}
# Losses {'ner': 3.243262186163158e-05}
# Losses {'ner': 3.243279719810496e-05}
# Losses {'ner': 3.243279797256438e-05}
# Losses {'ner': 3.243886337601568e-05}
# Losses {'ner': 3.244185850833541e-05}
# Losses {'ner': 3.2486316107606555e-05}
# Losses {'ner': 3.318273450200841e-05}
# Losses {'ner': 3.321944453761183e-05}
# Losses {'ner': 3.321944849723264e-05}
# Losses {'ner': 4.4198337202648866e-05}
# Losses {'ner': 4.421015482476411e-05}
# Losses {'ner': 4.421356347439208e-05}
# Losses {'ner': 4.4217276785726575e-05}
# Losses {'ner': 4.4217367736639656e-05}
# Losses {'ner': 4.4370488443612275e-05}
# Losses {'ner': 4.4492625335403136e-05}
# Losses {'ner': 4.47487906494034e-05}
# Losses {'ner': 4.474896460070242e-05}
# Losses {'ner': 5.8862058523514946e-05}
# Losses {'ner': 5.890128600150982e-05}
# Losses {'ner': 5.8901932137603335e-05}
# Losses {'ner': 5.891839008867972e-05}
# Losses {'ner': 5.892149059046943e-05}
# Losses {'ner': 5.8921997221677875e-05}
# Losses {'ner': 5.892295244893534e-05}
# Losses {'ner': 5.984729133392234e-05}
# Losses {'ner': 0.0002989080325967958}
# Losses {'ner': 0.0002989097621076281}
# Losses {'ner': 0.00029890976212413304}
# Losses {'ner': 0.00029890986859675093}
# Losses {'ner': 0.00029892683337223036}
# Losses {'ner': 0.0005361223835976577}
# Losses {'ner': 0.0005361835513738168}
# Losses {'ner': 0.0005361836160984024}
# Losses {'ner': 0.0005361837302123038}
# Losses {'ner': 0.0005361853601228935}
# Losses {'ner': 0.0005361854876572829}
# Losses {'ner': 0.0005374017303318245}
# Losses {'ner': 0.0005374101588497334}
# Losses {'ner': 0.0005374106904432634}
# Losses {'ner': 0.18557264358966888}
# Losses {'ner': 0.18557264363410686}
# Losses {'ner': 0.18557274011420302}
# Losses {'ner': 0.1967508066136284}
# Losses {'ner': 0.19675080663977892}
# Losses {'ner': 0.19675080677702372}
# Losses {'ner': 0.1968489587020786}
# Losses {'ner': 0.19685837117592428}
# Losses {'ner': 0.1968583711829573}
# Losses {'ner': 0.1968584479590213}
# Losses {'ner': 0.1968584498406084}
# Losses {'ner': 0.19685844986072393}
# Losses {'ner': 0.19685844986267714}
# Losses {'ner': 0.19685844986279508}
# Losses {'ner': 0.19685856979541852}
# Losses {'ner': 0.19685856979707017}
# Losses {'ner': 0.19685856979716687}
# Losses {'ner': 0.19685856981610428}
# Losses {'ner': 0.20057438816843046}
# Losses {'ner': 0.20057438875499498}
# Losses {'ner': 0.20057441491586117}
# Losses {'ner': 1.9438658345839056e-08}
# Losses {'ner': 8.526608669359016e-08}
# Losses {'ner': 1.005043053247947e-06}
# Losses {'ner': 1.0051041085511523e-06}
# Losses {'ner': 9.227170878885354e-06}
# Losses {'ner': 9.227190335243455e-06}
# Losses {'ner': 0.014980248753150762}
# Losses {'ner': 0.014980378484725929}
# Losses {'ner': 0.014980378484882905}
# Losses {'ner': 0.014980450082806724}
# Losses {'ner': 0.01509003605281301}
# Losses {'ner': 0.015090047599680323}
# Losses {'ner': 0.01509004761405481}
# Losses {'ner': 0.015090047792896941}
# Losses {'ner': 0.015125454403108604}
# Losses {'ner': 0.015125480689863047}
# Losses {'ner': 0.015125490194903623}
# Losses {'ner': 0.015125490199931466}
# Losses {'ner': 0.015125490363993261}
# Losses {'ner': 0.01512549036406528}
# Losses {'ner': 0.015126960507220025}
# Losses {'ner': 0.015126961032279567}
# Losses {'ner': 0.01512696103241547}
# Losses {'ner': 0.015127422002948414}
# Losses {'ner': 0.015127422004595345}
# Losses {'ner': 0.015339057027021506}
# Losses {'ner': 0.015339057045712189}
# Losses {'ner': 0.015339057106077457}
# Losses {'ner': 0.015339065098844399}
# Losses {'ner': 0.015339066416985462}
# Losses {'ner': 0.01533906700410473}
# Losses {'ner': 0.015339067018156797}
# Losses {'ner': 0.015339067946966973}
# Losses {'ner': 0.01533906794734058}
# Losses {'ner': 0.015339068039051012}
# Losses {'ner': 1.8270271341919722}
# Losses {'ner': 1.8270271342071163}
# Losses {'ner': 1.8270271342072046}
# Losses {'ner': 1.8270271342080877}
# Losses {'ner': 1.8270271447588946}
# Losses {'ner': 1.8328463965199087}
# Losses {'ner': 1.8328466145169038}
# Losses {'ner': 1.832846614561841}
# Losses {'ner': 1.8328466145618858}
# Losses {'ner': 1.8328466682959108}
# Losses {'ner': 1.8328467134221071}
# Losses {'ner': 1.8328467630565974}
# Losses {'ner': 1.832846763057052}
# Losses {'ner': 1.832848695031769}
# Losses {'ner': 1.832848695174105}
# Losses {'ner': 1.8328491826944577}
# Losses {'ner': 1.8328504113828321}
# Losses {'ner': 1.832851566784185}
# Losses {'ner': 1.8328515674247312}
# Losses {'ner': 1.8328515704784114}
# Losses {'ner': 1.8329257092348799}
# Losses {'ner': 1.8329257092736022}
# Losses {'ner': 1.8329257093199776}
# Losses {'ner': 1.8329257093219504}
# Losses {'ner': 1.8329257178002225}
# Losses {'ner': 1.8330738326982556}
# Losses {'ner': 1.833073832700384}
# Losses {'ner': 1.8330939180627726}
# Losses {'ner': 1.8331678952745005}
# Losses {'ner': 1.8331678952758945}
# Losses {'ner': 1.8331678953169932}
# Losses {'ner': 1.8331682133232363}
# Losses {'ner': 1.833168215203975}
# Losses {'ner': 1.833168215203976}
# Losses {'ner': 1.833168215205484}
# Losses {'ner': 3.680935687620822}
# Losses {'ner': 3.6809356876321693}
# Losses {'ner': 3.680935687763784}
# Losses {'ner': 3.6809356883995434}
# Losses {'ner': 3.6809361148957507}
# Losses {'ner': 3.6809362520564113}
# Losses {'ner': 3.680936252179656}
# Losses {'ner': 3.6809362684635967}
# Losses {'ner': 3.680936270779224}
# Losses {'ner': 3.68093627077978}
# Losses {'ner': 4.206412965176153}
# Losses {'ner': 4.206412965206324}
# Losses {'ner': 4.206412966234538}
# Losses {'ner': 4.206412966235178}
# Losses {'ner': 4.206413070149875}
# Losses {'ner': 4.206413070156864}
# Losses {'ner': 4.2064130702417195}
# Losses {'ner': 4.2064130702432285}
# Losses {'ner': 5.979247132837777}
# Losses {'ner': 5.979247132841467}
# Losses {'ner': 5.979247401189655}
# Losses {'ner': 5.979247401193349}
# Losses {'ner': 5.9792474035947345}
# Losses {'ner': 5.979247403595034}
# Losses {'ner': 5.979247403606589}
# Losses {'ner': 5.979247403610752}
# Losses {'ner': 5.979247403618667}
# Losses {'ner': 5.979247403630969}
# Losses {'ner': 5.979247403631206}
# Losses {'ner': 6.5748041415401435}
# Losses {'ner': 5.540865777842314e-12}
# Losses {'ner': 5.065463089913769e-08}
# Losses {'ner': 5.184280100211523e-08}
# Losses {'ner': 6.963864077466833e-08}
# Losses {'ner': 6.964524175868721e-08}
# Losses {'ner': 6.965345374878072e-08}
# Losses {'ner': 6.965385929697882e-08}
# Losses {'ner': 6.965387833014497e-08}
# Losses {'ner': 6.597717849479265e-07}
# Losses {'ner': 6.598575527146165e-07}
# Losses {'ner': 6.598577609885763e-07}
# Losses {'ner': 6.602745250271945e-07}
# Losses {'ner': 6.60646054885847e-07}
# Losses {'ner': 6.726195111816431e-07}
# Losses {'ner': 6.0923205319823746e-06}
# Losses {'ner': 5.65933817290471e-05}
# Losses {'ner': 5.6593383419527544e-05}
# Losses {'ner': 0.05559892829797637}
# Losses {'ner': 0.05559892829823252}
# Losses {'ner': 0.055599094582394266}
# Losses {'ner': 0.055599094588761826}
# Losses {'ner': 0.05559910381106441}
# Losses {'ner': 0.05559910381132216}
# Losses {'ner': 0.05559910383025275}
# Losses {'ner': 0.055896645967813886}
# Losses {'ner': 0.05589664598635657}
# Losses {'ner': 0.33188978453848106}
# Losses {'ner': 0.3318897845623949}
# Losses {'ner': 0.33188978465700214}
# Losses {'ner': 0.3318897846584389}
# Losses {'ner': 0.3319585833636557}
# Losses {'ner': 0.33205495990510625}
# Losses {'ner': 0.33205495999249063}
# Losses {'ner': 0.3320549599974616}
# Losses {'ner': 0.33205496000172846}
# Losses {'ner': 0.3320550038330318}
# Losses {'ner': 0.33206248991340054}
# Losses {'ner': 0.33206249007733885}
# Losses {'ner': 0.33206249093764134}
# Losses {'ner': 0.3320624951626166}
# Losses {'ner': 0.3321817190366536}
# Losses {'ner': 0.33218171906599153}
# Losses {'ner': 0.3321817191668575}
# Losses {'ner': 0.3321817232644825}
# Losses {'ner': 0.3321817232781206}
# Losses {'ner': 0.3321817338408525}
# Losses {'ner': 0.3327041649583437}
# Losses {'ner': 0.3327041649584702}
# Losses {'ner': 0.3327041650929038}
# Losses {'ner': 0.33270416641936656}
# Losses {'ner': 0.33270416645442696}
# Losses {'ner': 0.3327041664624107}
# Losses {'ner': 0.3327041664853107}
# Losses {'ner': 0.3327041665161269}
# Losses {'ner': 0.33270422350764595}
# Losses {'ner': 0.3327043597168801}
# Losses {'ner': 0.3327043597196913}
# Losses {'ner': 0.33270508909399044}
# Losses {'ner': 0.33270509024194045}
# Losses {'ner': 0.3329209967002457}
# Losses {'ner': 0.33292099670117675}
# Losses {'ner': 0.3329209967116579}
# Losses {'ner': 0.3329210495037835}
# Losses {'ner': 0.33292104953677915}
# Losses {'ner': 0.33293621365460796}
# Losses {'ner': 0.3329362136632107}
# Losses {'ner': 0.3331367489954236}
# Losses {'ner': 0.3331404771664546}
# Losses {'ner': 0.333140477166523}
# Losses {'ner': 0.33314047717422773}
# Losses {'ner': 0.33314047723358925}
# Losses {'ner': 0.33314049497960363}
# Losses {'ner': 0.3331405474929514}
# Losses {'ner': 0.3331405474929951}
# Losses {'ner': 0.3331405474942175}
# Losses {'ner': 0.3331461126157941}
# Losses {'ner': 0.3331461126183221}
# Losses {'ner': 0.33314611271582384}
# Losses {'ner': 0.3331461127158502}
# Losses {'ner': 0.33314622119581816}
# Losses {'ner': 0.3331462211958779}
# Losses {'ner': 0.3331462214072121}
# Losses {'ner': 0.3331462214072567}
# Losses {'ner': 0.3331519238508473}
# Losses {'ner': 0.3331519241217609}
# Losses {'ner': 0.3331519242074102}
# Losses {'ner': 0.3331519242350958}
# Losses {'ner': 0.3331519253325278}
# Losses {'ner': 0.3331519300742375}
# Losses {'ner': 0.33315193138472166}
# Losses {'ner': 0.33315193138594235}
# Losses {'ner': 0.3331520680588781}
# Losses {'ner': 0.3331520888772734}
# Losses {'ner': 0.3331527566590748}
# Losses {'ner': 1.7735519674885435e-07}
# Losses {'ner': 1.2510324321418086e-06}
# Losses {'ner': 1.2517540572834519e-06}
# Losses {'ner': 1.25190436917414e-06}
# Losses {'ner': 1.252466578664084e-06}
# Losses {'ner': 1.2524688992973075e-06}
# Losses {'ner': 0.0004959944538650473}
# Losses {'ner': 0.00049600649400362}
# Losses {'ner': 0.0004960066823169062}
# Losses {'ner': 0.0005076367885252744}
# Losses {'ner': 0.0005077046426458107}
# Losses {'ner': 0.0005077320593200098}
# Losses {'ner': 0.0005077384318249237}
# Losses {'ner': 0.0005077385083038391}
# Losses {'ner': 0.02153562947698226}
# Losses {'ner': 0.021535895340635002}
# Losses {'ner': 0.025036983585630203}
# Losses {'ner': 0.030645406602297247}
# Losses {'ner': 0.030670331577714764}
# Losses {'ner': 0.03067033371581997}
# Losses {'ner': 0.12377186542772727}
# Losses {'ner': 0.12377186542794047}
# Losses {'ner': 0.12377186598849149}
# Losses {'ner': 0.12377186793554239}
# Losses {'ner': 0.12377186980170818}
# Losses {'ner': 0.12377203243784964}
# Losses {'ner': 0.12377458431868818}
# Losses {'ner': 0.14980436484579743}
# Losses {'ner': 0.1498043656836789}
# Losses {'ner': 0.1498043778677567}
# Losses {'ner': 0.14980442483490752}
# Losses {'ner': 1.0807173738937008}
# Losses {'ner': 1.0807173738961817}
# Losses {'ner': 1.0807173740264169}
# Losses {'ner': 1.0807173741921468}
# Losses {'ner': 1.0815996944667052}
# Losses {'ner': 1.0815996944668924}
# Losses {'ner': 1.0815996992382781}
# Losses {'ner': 1.081599713162147}
# Losses {'ner': 1.081599716513903}
# Losses {'ner': 1.0815997171568406}
# Losses {'ner': 1.0816100195365057}
# Losses {'ner': 1.0816100923320318}
# Losses {'ner': 1.0816102062265158}
# Losses {'ner': 1.081610206227127}
# Losses {'ner': 1.0816102062276514}
# Losses {'ner': 1.081611202862386}
# Losses {'ner': 1.0816560283113839}
# Losses {'ner': 1.081656028319752}
# Losses {'ner': 1.0816560283319578}
# Losses {'ner': 1.1621311201644442e-11}
# Losses {'ner': 2.138291429649144e-11}
# Losses {'ner': 2.1625975912360874e-11}
# Losses {'ner': 0.0002374155814552541}
# Losses {'ner': 0.00023746131775616728}
# Losses {'ner': 0.0002374617368550738}
# Losses {'ner': 0.0002374617525324016}
# Losses {'ner': 0.00023746187586203344}
# Losses {'ner': 0.00023747253951276245}
# Losses {'ner': 0.00023747456559543664}
# Losses {'ner': 0.1747246034467486}
# Losses {'ner': 0.18812845884474189}
# Losses {'ner': 0.18812848548244293}
# Losses {'ner': 0.1881284855919009}
# Losses {'ner': 0.18812848616583303}
# Losses {'ner': 0.1881284862462007}
# Losses {'ner': 0.1881284862467356}
# Losses {'ner': 0.18812848640138277}
# Losses {'ner': 0.188128486401406}
# Losses {'ner': 0.1881284906066553}
# Losses {'ner': 0.1881284906077156}
# Losses {'ner': 0.1881284906266446}
# Losses {'ner': 0.18812849481685165}
# Losses {'ner': 0.1881284948231033}
# Losses {'ner': 0.18812849491378922}
# Losses {'ner': 0.18812849494335934}
# Losses {'ner': 0.18820507305955886}
# Losses {'ner': 0.18820507631244612}
# Losses {'ner': 0.188205076312458}
# Losses {'ner': 0.18820507631500005}
# Losses {'ner': 0.18855394705279127}
# Losses {'ner': 0.18856706555543973}
# Losses {'ner': 0.18856706562087203}
# Losses {'ner': 0.1885681730180998}
# Losses {'ner': 0.1885681731535449}
# Losses {'ner': 0.1885681824744857}
# Losses {'ner': 0.1885705252587635}
# Losses {'ner': 0.18857052527821933}
# Losses {'ner': 0.1885705252795616}
# Losses {'ner': 0.18857052528156323}
# Losses {'ner': 0.1885705254455594}
# Losses {'ner': 0.18857052544695335}
# Losses {'ner': 0.18857052625196966}
# Losses {'ner': 0.18870048601716075}
# Losses {'ner': 0.18870048602397946}
# Losses {'ner': 0.18870048694078867}
# Losses {'ner': 0.18870048694087227}
# Losses {'ner': 0.1887004870937296}
# Losses {'ner': 0.18870048720319613}
# Losses {'ner': 0.18871723025691137}
# Losses {'ner': 4.60851031143231e-09}
# Losses {'ner': 7.06505281824458e-09}
# Losses {'ner': 7.079517498143585e-09}
# Losses {'ner': 7.090624053132985e-09}
# Losses {'ner': 7.097181493640707e-09}
# Losses {'ner': 7.098315721662521e-09}
# Losses {'ner': 7.1633601455762315e-09}
# Losses {'ner': 1.1377156074376248e-08}
# Losses {'ner': 1.1377720529969245e-08}
# Losses {'ner': 2.090099716048451e-06}
# Losses {'ner': 2.090099771367099e-06}
# Losses {'ner': 2.0900998695577436e-06}
# Losses {'ner': 2.0901429975975247e-06}
# Losses {'ner': 2.107642304662257e-06}
# Losses {'ner': 0.0008358169455325378}
# Losses {'ner': 0.0008358169673708736}
# Losses {'ner': 0.0008360567104369373}
# Losses {'ner': 0.0008360567106980444}
# Losses {'ner': 0.000836056809607032}
# Losses {'ner': 0.0008360568196120072}
# Losses {'ner': 0.0008360568470685804}
# Losses {'ner': 0.0008388291897570857}
# Losses {'ner': 0.0008388535099726812}
# Losses {'ner': 0.0008389051224530004}
# Losses {'ner': 0.0008389051227032495}
# Losses {'ner': 0.0008389051443498107}
# Losses {'ner': 0.0008389051522420798}
# Losses {'ner': 0.0008389052066035635}
# Losses {'ner': 0.0008389052066041907}
# Losses {'ner': 0.0008389165072803641}
# Losses {'ner': 0.0008389166461722816}
# Losses {'ner': 0.0008395389259301619}
# Losses {'ner': 0.0008395389338187915}
# Losses {'ner': 0.0008395435690588904}
# Losses {'ner': 0.0008395435756333785}
# Losses {'ner': 0.0008396131348725085}
# Losses {'ner': 0.0008396131615546335}
# Losses {'ner': 0.0008396131623286322}
# Losses {'ner': 0.0008396131684273021}
# Losses {'ner': 0.000839617077405526}
# Losses {'ner': 0.0008396171458531224}
# Losses {'ner': 0.0008396171461016227}
# Losses {'ner': 0.0008790679392930949}
# Losses {'ner': 0.0008790680468402877}
# Losses {'ner': 0.0008790680516021017}
# Losses {'ner': 0.000879080148746877}
# Losses {'ner': 0.0008790801491911776}
# Losses {'ner': 0.0008790801569795288}
# Losses {'ner': 0.0008790801570727062}
# Losses {'ner': 0.0008790801572015844}
# Losses {'ner': 1.2867306222963423e-10}
# Losses {'ner': 2.08615327122384e-10}
# Losses {'ner': 2.0879243277132738e-10}
# Losses {'ner': 8.603237640523039e-06}
# Losses {'ner': 8.621277579949082e-06}
# Losses {'ner': 5.208489799242804e-05}
# Losses {'ner': 0.0012484699226616035}
# Losses {'ner': 0.0012484699308398153}
# Losses {'ner': 0.001248497699913733}
# Losses {'ner': 0.0012485042532978266}
# Losses {'ner': 0.001248504253403686}
# Losses {'ner': 0.0012485043001106253}
# Losses {'ner': 0.00124850430483393}
# Losses {'ner': 0.0012510462780487596}
# Losses {'ner': 0.0012510462782745885}
# Losses {'ner': 0.0012510466030147458}
# Losses {'ner': 0.0012510495742667654}
# Losses {'ner': 0.0012510497921797222}
# Losses {'ner': 0.0012510497938012662}
# Losses {'ner': 0.0012510497986106634}
# Losses {'ner': 0.001251049799955378}
# Losses {'ner': 0.0013906630579302445}
# Losses {'ner': 0.0013907110896075622}
# Losses {'ner': 0.0013907110900599677}
# Losses {'ner': 0.0013907110904035098}
# Losses {'ner': 0.0013907133657935782}
# Losses {'ner': 0.0013907133669086764}
# Losses {'ner': 0.001390713452925108}
# Losses {'ner': 0.0013907351571080604}
# Losses {'ner': 0.0013907352543843273}
# Losses {'ner': 0.0013907357504939497}
# Losses {'ner': 0.0013907357567091612}
# Losses {'ner': 0.0013907738900518591}
# Losses {'ner': 0.001390773891316455}
# Losses {'ner': 0.0013908019415995424}
# Losses {'ner': 0.0013908024129897609}
# Losses {'ner': 0.0013908024131841464}
# Losses {'ner': 0.0013908024391601683}
# Losses {'ner': 0.0013908026008509118}
# Losses {'ner': 0.001390802665266655}
# Losses {'ner': 0.0013908198213601086}
# Losses {'ner': 0.001390822366006735}
# Losses {'ner': 0.0013908225406194488}
# Losses {'ner': 0.001390822541490102}
# Losses {'ner': 0.0013908225436152942}
# Losses {'ner': 0.0013908227637849178}
# Losses {'ner': 0.0013917690670457008}
# Losses {'ner': 0.0013917690693852692}
# Losses {'ner': 0.001391907720781748}
# Losses {'ner': 0.0013919530693495721}
# Losses {'ner': 4.3131381551213043e-13}
# Losses {'ner': 8.194774861373355e-08}
# Losses {'ner': 8.195681783953063e-08}
# Losses {'ner': 6.014044404137355e-07}
# Losses {'ner': 6.014460320216833e-07}
# Losses {'ner': 6.015599726500272e-07}
# Losses {'ner': 0.00937004520676795}
# Losses {'ner': 0.009370075069022649}
# Losses {'ner': 0.009370100002460026}
# Losses {'ner': 0.00937015956226907}
# Losses {'ner': 0.009370159563630732}
# Losses {'ner': 0.009370159565931908}
# Losses {'ner': 0.009370159607123953}
# Losses {'ner': 0.009370159627666122}
# Losses {'ner': 0.009370159627963474}
# Losses {'ner': 0.009370159631906471}
# Losses {'ner': 0.009370159652464072}
# Losses {'ner': 0.009370159652570967}
# Losses {'ner': 0.009375612557218499}
# Losses {'ner': 0.041881825149405943}
# Losses {'ner': 0.04188182516185834}
# Losses {'ner': 0.04188182516576808}
# Losses {'ner': 0.04188184127718073}
# Losses {'ner': 0.04188191476370947}
# Losses {'ner': 0.041881914847985216}
# Losses {'ner': 0.0418819148490611}
# Losses {'ner': 0.04188313489504902}
# Losses {'ner': 0.041883135100990024}
# Losses {'ner': 0.04188316411520773}
# Losses {'ner': 0.04226723840176757}
# Losses {'ner': 0.04226723840188567}
# Losses {'ner': 0.04226723840188571}
# Losses {'ner': 0.04226723858790131}
# Losses {'ner': 0.042267238632587606}
# Losses {'ner': 0.04226724212709478}
# Losses {'ner': 0.04226724282907716}
# Losses {'ner': 0.04226724387345232}
# Losses {'ner': 0.04226724387351708}
# Losses {'ner': 0.0422672462492129}
# Losses {'ner': 0.04226724624922085}
# Losses {'ner': 0.042267246249383654}
# Losses {'ner': 0.042267246263562396}
# Losses {'ner': 0.04226724626429333}
# Losses {'ner': 0.04226724626734235}
# Losses {'ner': 0.042267247443506954}
# Losses {'ner': 0.04226894200348827}
# Losses {'ner': 0.04226894200351847}
# Losses {'ner': 0.04226894200352647}
# Losses {'ner': 0.04226895787240079}
# Losses {'ner': 0.10895250358105849}
# Losses {'ner': 6.107139958199689e-16}
# Losses {'ner': 1.0060607362267257e-13}
# Losses {'ner': 1.0342501268876458e-13}
# Losses {'ner': 1.601441598167863e-12}
# Losses {'ner': 1.354600440029873e-08}
# Losses {'ner': 0.12190835042382729}
# Losses {'ner': 0.12190835053825563}
# Losses {'ner': 0.12190835054049469}
# Losses {'ner': 0.12190835054584127}
# Losses {'ner': 0.12190835065666003}
# Losses {'ner': 0.12190849252963058}
# Losses {'ner': 0.12190849253144621}
# Losses {'ner': 0.12190849253144881}
# Losses {'ner': 0.1219084925484949}
# Losses {'ner': 0.12190849254850004}
# Losses {'ner': 0.12190849255823324}
# Losses {'ner': 0.12190850314812031}
# Losses {'ner': 0.12190850314834976}
# Losses {'ner': 0.12190850314856547}
# Losses {'ner': 0.12190850315202259}
# Losses {'ner': 0.12190850315516387}
# Losses {'ner': 0.12190850316868383}
# Losses {'ner': 0.1219091777243909}
# Losses {'ner': 0.12190917785237133}
# Losses {'ner': 0.12190917786339567}
# Losses {'ner': 0.12190918904139308}
# Losses {'ner': 0.12190918904140055}
# Losses {'ner': 0.12190918904163789}
# Losses {'ner': 0.12190919674708779}
# Losses {'ner': 0.12190920717257596}
# Losses {'ner': 0.12190920717257848}
# Losses {'ner': 0.1219092071728748}
# Losses {'ner': 0.12190920718849256}
# Losses {'ner': 0.12190920934174306}
# Losses {'ner': 0.12190920935112386}
# Losses {'ner': 0.12190920935116012}
# Losses {'ner': 0.12195291654088586}
# Losses {'ner': 0.12195291969551811}
# Losses {'ner': 0.12195291969605929}
# Losses {'ner': 0.12195291969607244}
# Losses {'ner': 0.12195291969607859}
# Losses {'ner': 0.12195291969609752}
# Losses {'ner': 0.12195292122783234}
# Losses {'ner': 0.12195292236395823}
# Losses {'ner': 0.12195292238272215}
# Losses {'ner': 0.12195292238648799}
# Losses {'ner': 0.12195292238683192}
# Losses {'ner': 0.12195292664768098}
# Losses {'ner': 0.12195292679297745}
# Losses {'ner': 0.12195292679297848}
# Losses {'ner': 1.2897645236171745e-11}
# Losses {'ner': 7.611501803641588e-10}
# Losses {'ner': 0.000421894837040005}
# Losses {'ner': 0.00042189483707771375}
# Losses {'ner': 0.0004218948370782275}
# Losses {'ner': 0.00042189484304181016}
# Losses {'ner': 0.0004218950176542541}
# Losses {'ner': 0.00042189580477058024}
# Losses {'ner': 0.00042189595836172514}
# Losses {'ner': 0.0004218959583696741}
# Losses {'ner': 0.0004218959614446508}
# Losses {'ner': 0.000421948224445501}
# Losses {'ner': 0.0004219482281228058}
# Losses {'ner': 0.00042194928524854096}
# Losses {'ner': 0.0004219492859348728}
# Losses {'ner': 0.0008769822910600983}
# Losses {'ner': 0.0008769822910601125}
# Losses {'ner': 0.0009265324624994032}
# Losses {'ner': 0.000926532463099821}
# Losses {'ner': 0.000926629520804766}
# Losses {'ner': 0.0011918426287278305}
# Losses {'ner': 0.0011918426295396537}
# Losses {'ner': 0.0011918426381163356}
# Losses {'ner': 0.0011918460652613567}
# Losses {'ner': 0.0011918859219894559}
# Losses {'ner': 0.0011918863902277053}
# Losses {'ner': 0.0011918914943741315}
# Losses {'ner': 0.002947648518886837}
# Losses {'ner': 0.0029476485188868586}
# Losses {'ner': 0.002947648536714248}
# Losses {'ner': 0.002947648646819521}
# Losses {'ner': 0.0029476486469342264}
# Losses {'ner': 0.0029476486469467576}
# Losses {'ner': 0.0029476486470241103}
# Losses {'ner': 0.0029476486483781057}
# Losses {'ner': 0.0029476535813313365}
# Losses {'ner': 0.0029480792269060544}
# Losses {'ner': 0.0029480792269062127}
# Losses {'ner': 0.003197607548358488}
# Losses {'ner': 0.0031976075486500805}
# Losses {'ner': 0.003197607548651367}
# Losses {'ner': 0.003197607548651406}
# Losses {'ner': 0.003197704329739117}
# Losses {'ner': 0.003197704329744671}
# Losses {'ner': 0.003198922005261826}
# Losses {'ner': 0.0031989220058737905}
# Losses {'ner': 0.003198922012794024}
# Losses {'ner': 0.0031991612692163266}
# Losses {'ner': 0.00319916127661936}
# Losses {'ner': 0.003199161654234028}
# Losses {'ner': 1.074813937907297e-12}
# Losses {'ner': 2.2943052688764777e-09}
# Losses {'ner': 2.2951887672830946e-09}
# Losses {'ner': 2.6168710833044117e-08}
# Losses {'ner': 6.662883072947765e-07}
# Losses {'ner': 6.662932192366307e-07}
# Losses {'ner': 2.1035592836226885e-06}
# Losses {'ner': 2.103559283727257e-06}
# Losses {'ner': 2.103559283754171e-06}
# Losses {'ner': 2.1035592843085345e-06}
# Losses {'ner': 2.114204613258759e-06}
# Losses {'ner': 2.1142592975788965e-06}
# Losses {'ner': 3.915193661846205e-06}
# Losses {'ner': 3.915195848632227e-06}
# Losses {'ner': 3.918263799923515e-06}
# Losses {'ner': 3.918264354209421e-06}
# Losses {'ner': 3.918275740845701e-06}
# Losses {'ner': 3.941014257183817e-06}
# Losses {'ner': 3.941014257493452e-06}
# Losses {'ner': 3.941016421551045e-06}
# Losses {'ner': 3.9410164267502765e-06}
# Losses {'ner': 3.941016426750729e-06}
# Losses {'ner': 4.195635679351199e-06}
# Losses {'ner': 4.195635679372108e-06}
# Losses {'ner': 4.195635691629355e-06}
# Losses {'ner': 4.200806430551913e-06}
# Losses {'ner': 4.2008064321479454e-06}
# Losses {'ner': 0.0002285163969085713}
# Losses {'ner': 0.00022851639707511346}
# Losses {'ner': 0.000228565472671197}
# Losses {'ner': 0.00022856547267342874}
# Losses {'ner': 0.00022856547267429594}
# Losses {'ner': 0.00022856547268042656}
# Losses {'ner': 0.00022856547270551302}
# Losses {'ner': 0.00022856547270841087}
# Losses {'ner': 0.00022856547270849904}
# Losses {'ner': 0.0002285654733084748}
# Losses {'ner': 0.00022856547331480845}
# Losses {'ner': 0.00022856547336010764}
# Losses {'ner': 0.00022856550657563413}
# Losses {'ner': 0.00022856550657564343}
# Losses {'ner': 0.00024807588344590904}
# Losses {'ner': 0.0002480779257259507}
# Losses {'ner': 0.0002480780599505865}
# Losses {'ner': 0.00024817762419095265}
# Losses {'ner': 0.00024817765982567726}
# Losses {'ner': 0.00024817765983664797}
# Losses {'ner': 0.00024817765983665307}
# Losses {'ner': 1.3305726794594926e-07}
# Losses {'ner': 1.3305727690810092e-07}
# Losses {'ner': 1.3305732807598494e-07}
# Losses {'ner': 1.3385668849027044e-07}
# Losses {'ner': 1.340928461019458e-07}
# Losses {'ner': 1.3409303834053132e-07}
# Losses {'ner': 0.01000455598527597}
# Losses {'ner': 0.010004810258723844}
# Losses {'ner': 0.010004810263810268}
# Losses {'ner': 0.01000481124646584}
# Losses {'ner': 0.010123709537007614}
# Losses {'ner': 0.041882297734654184}
# Losses {'ner': 0.041882297737780544}
# Losses {'ner': 0.04188229778980418}
# Losses {'ner': 0.04188229779152258}
# Losses {'ner': 0.04188229779284753}
# Losses {'ner': 0.04188229792004797}
# Losses {'ner': 0.041882297920919645}
# Losses {'ner': 0.04188229792092073}
# Losses {'ner': 0.041882297921399456}
# Losses {'ner': 0.04188229792139988}
# Losses {'ner': 0.041882297921441165}
# Losses {'ner': 0.041882298674325774}
# Losses {'ner': 0.04188229876477433}
# Losses {'ner': 0.041893746947763516}
# Losses {'ner': 0.04189374694783691}
# Losses {'ner': 0.04189374694784544}
# Losses {'ner': 0.04189374695472193}
# Losses {'ner': 0.04189374695472347}
# Losses {'ner': 0.04189374697286466}
# Losses {'ner': 0.04189374697900458}
# Losses {'ner': 0.041893746979247304}
# Losses {'ner': 0.04189374698267894}
# Losses {'ner': 0.041893746982684596}
# Losses {'ner': 7.97620390824324e-13}
# Losses {'ner': 1.2190445068860328e-12}
# Losses {'ner': 2.9341469007882786e-11}
# Losses {'ner': 2.997678103347943e-11}
# Losses {'ner': 1.8295687748542596e-10}
# Losses {'ner': 7.543864023596244e-06}
# Losses {'ner': 7.543864028232142e-06}
# Losses {'ner': 7.5438640711654235e-06}
# Losses {'ner': 7.543864334417313e-06}
# Losses {'ner': 7.547481705853416e-06}
# Losses {'ner': 7.587913356240399e-06}
# Losses {'ner': 7.588053016187901e-06}
# Losses {'ner': 7.588053146885715e-06}
# Losses {'ner': 7.588127760784496e-06}
# Losses {'ner': 7.588127817186063e-06}
# Losses {'ner': 7.588127821645466e-06}
# Losses {'ner': 7.588127870719036e-06}
# Losses {'ner': 1.990174024072273}
# Losses {'ner': 1.9901740240722732}
# Losses {'ner': 1.990174024357651}
# Losses {'ner': 1.9901740254663298}
# Losses {'ner': 1.9901740254665246}
# Losses {'ner': 1.990174025631678}
# Losses {'ner': 1.992505036080833}
# Losses {'ner': 1.9925050426473598}
# Losses {'ner': 1.99250504264754}
# Losses {'ner': 1.9925059360579416}
# Losses {'ner': 1.992505936156251}
# Losses {'ner': 1.9925059361565265}
# Losses {'ner': 1.9925087410500182}
# Losses {'ner': 1.9925088113331306}
# Losses {'ner': 1.9925088113331308}
# Losses {'ner': 1.9925088113331308}
# Losses {'ner': 1.9925088113335134}
# Losses {'ner': 4.5343307314511174e-10}
# Losses {'ner': 4.534424352776212e-10}
# Losses {'ner': 3.0808457941140297e-09}
# Losses {'ner': 3.440812023391845e-09}
# Losses {'ner': 3.4408543937099175e-09}
# Losses {'ner': 3.4975172810847113e-09}
# Losses {'ner': 8.04639690548397e-05}
# Losses {'ner': 8.114392760329496e-05}
# Losses {'ner': 0.012323436912930594}
# Losses {'ner': 0.012323436912933576}
# Losses {'ner': 0.012323436912939183}
# Losses {'ner': 0.012323436912939202}
# Losses {'ner': 0.01232343691316474}
# Losses {'ner': 0.012323436913164848}
# Losses {'ner': 0.014802629015595559}
# Losses {'ner': 0.014802629015911884}
# Losses {'ner': 0.01480262901843492}
# Losses {'ner': 0.01480328747382751}
# Losses {'ner': 0.014803287481053072}
# Losses {'ner': 0.014803287481053163}
# Losses {'ner': 0.014803289362798976}
# Losses {'ner': 0.01480328937553505}
# Losses {'ner': 0.014803289379662847}
# Losses {'ner': 0.01480328937969176}
# Losses {'ner': 0.014803290334523917}
# Losses {'ner': 0.014803290334856483}
# Losses {'ner': 0.0159715716069242}
# Losses {'ner': 0.01597157161616426}
# Losses {'ner': 0.015971571623438544}
# Losses {'ner': 0.0159715716388375}
# Losses {'ner': 0.015976054868456706}
# Losses {'ner': 0.01597605486985958}
# Losses {'ner': 0.015976054869860763}
# Losses {'ner': 0.015976054869862893}
# Losses {'ner': 9.685920396721826e-10}
# Losses {'ner': 9.68614405142818e-10}
# Losses {'ner': 9.721974353816825e-10}
# Losses {'ner': 9.81792105657674e-10}
# Losses {'ner': 9.825929186456326e-10}
# Losses {'ner': 6.145514290678208e-09}
# Losses {'ner': 6.193479670548452e-09}
# Losses {'ner': 6.231681744908212e-09}
# Losses {'ner': 6.2317876287110214e-09}
# Losses {'ner': 6.232836182355164e-09}
# Losses {'ner': 6.233234910640642e-09}
# Losses {'ner': 6.233247434831789e-09}
# Losses {'ner': 6.233247718044092e-09}
# Losses {'ner': 6.233463633749827e-09}
# Losses {'ner': 6.237705074163291e-09}
# Losses {'ner': 6.237744160687214e-09}
# Losses {'ner': 6.237795555730699e-09}
# Losses {'ner': 1.164119361680047e-08}
# Losses {'ner': 1.1799853879201871e-08}
# Losses {'ner': 1.1847623888731941e-08}
# Losses {'ner': 0.003525594974923285}
# Losses {'ner': 0.003525595284898455}
# Losses {'ner': 0.0035255952969751596}
# Losses {'ner': 0.0035255952975927506}
# Losses {'ner': 0.003525595298069823}
# Losses {'ner': 0.0035255953420766884}
# Losses {'ner': 0.0035255956005828585}
# Losses {'ner': 0.003525595748069659}
# Losses {'ner': 0.0035255957513387853}
# Losses {'ner': 0.0035255959670007836}
# Losses {'ner': 0.0035255959691254065}
# Losses {'ner': 0.0035256017572668774}
# Losses {'ner': 0.0035256018847296777}
# Losses {'ner': 0.003525601925361606}
# Losses {'ner': 4.213586932660495e-13}
# Losses {'ner': 4.378228444098174e-10}
# Losses {'ner': 4.769398982235724e-10}
# Losses {'ner': 8.555220804459934e-10}
# Losses {'ner': 2.9652465811359323e-09}
# Losses {'ner': 4.4898851624786794e-09}
# Losses {'ner': 9.729260478232285e-09}
# Losses {'ner': 9.730508979362057e-09}
# Losses {'ner': 9.732733035683694e-09}
# Losses {'ner': 9.732773674109094e-09}
# Losses {'ner': 9.735565100124632e-09}
# Losses {'ner': 3.443565925238182e-08}
# Losses {'ner': 0.00010618891836648271}
# Losses {'ner': 0.00010619649537220868}
# Losses {'ner': 0.00010619649773973972}
# Losses {'ner': 0.00010619649908251633}
# Losses {'ner': 0.00010619649927692777}
# Losses {'ner': 0.00010619649931980361}
# Losses {'ner': 0.00010619652209872407}
# Losses {'ner': 0.0001062006160644912}
# Losses {'ner': 0.00010620061610097904}
# Losses {'ner': 0.00010620061610690979}
# Losses {'ner': 0.00010620061990975862}
# Losses {'ner': 0.00010620061991012622}
# Losses {'ner': 0.00010620062553841765}
# Losses {'ner': 0.00010620103246985612}
# Losses {'ner': 0.00010623708103676904}
# Losses {'ner': 0.0001960675559367038}
# Losses {'ner': 0.00019619436325113714}
# Losses {'ner': 0.0001961943647302606}
# Losses {'ner': 0.00019619611631230307}
# Losses {'ner': 0.00019619624339382657}
# Losses {'ner': 0.00019619624345271758}
# Losses {'ner': 0.00019619624345271794}
# Losses {'ner': 1.5647535424870412e-14}
# Losses {'ner': 2.2745479136557176e-13}
# Losses {'ner': 1.3636333687017188e-06}
# Losses {'ner': 1.363674318391474e-06}
# Losses {'ner': 1.3636869515174196e-06}
# Losses {'ner': 1.363686963374e-06}
# Losses {'ner': 1.3636875025172315e-06}
# Losses {'ner': 1.3636882541049547e-06}
# Losses {'ner': 1.3636882941305092e-06}
# Losses {'ner': 1.3637209317315307e-06}
# Losses {'ner': 1.3637211015650317e-06}
# Losses {'ner': 1.3637213144513946e-06}
# Losses {'ner': 1.3637220605658948e-06}
# Losses {'ner': 1.364233012592665e-06}
# Losses {'ner': 1.364233118447017e-06}
# Losses {'ner': 1.364233157770576e-06}
# Losses {'ner': 1.3645597153363954e-06}
# Losses {'ner': 1.3645597156076236e-06}
# Losses {'ner': 1.3648268086519378e-06}
# Losses {'ner': 1.3648299473507086e-06}
# Losses {'ner': 1.3649807169377834e-06}
# Losses {'ner': 1.3767241266054898e-06}
# Losses {'ner': 1.3767307105206772e-06}
# Losses {'ner': 1.3767307248658455e-06}
# Losses {'ner': 1.3767307248832035e-06}
# Losses {'ner': 1.3767309930353297e-06}
# Losses {'ner': 1.3767309977911023e-06}
# Losses {'ner': 1.3767310020209206e-06}
# Losses {'ner': 1.3767314058130246e-06}
# Losses {'ner': 1.3767314061623683e-06}
# Losses {'ner': 9.62964605632764e-06}
# Losses {'ner': 9.629682960454892e-06}
# Losses {'ner': 9.629693133486807e-06}
# Losses {'ner': 9.629693133499842e-06}
# Losses {'ner': 4.787402426742622e-12}
# Losses {'ner': 4.851158630719719e-12}
# Losses {'ner': 2.3288810037000066e-11}
# Losses {'ner': 3.1884355881414946e-11}
# Losses {'ner': 7.896150429653698e-11}
# Losses {'ner': 3.817772662389669e-08}
# Losses {'ner': 1.240988786754694e-07}
# Losses {'ner': 1.2410005498204139e-07}
# Losses {'ner': 1.804973989266357e-07}
# Losses {'ner': 1.806511997776044e-07}
# Losses {'ner': 1.806974978892908e-07}
# Losses {'ner': 1.919254749465222e-07}
# Losses {'ner': 1.919254749483633e-07}
# Losses {'ner': 1.9192556704028016e-07}
# Losses {'ner': 1.9192571926980438e-07}
# Losses {'ner': 1.9258704870338838e-07}
# Losses {'ner': 1.9258704924352025e-07}
# Losses {'ner': 1.9265301197727746e-07}
# Losses {'ner': 1.926604484993656e-07}
# Losses {'ner': 1.9266617881713615e-07}
# Losses {'ner': 1.9266617910181018e-07}
# Losses {'ner': 1.9268657091821893e-07}
# Losses {'ner': 1.9269486881649091e-07}
# Losses {'ner': 1.9269624960989088e-07}
# Losses {'ner': 1.9269785196281908e-07}
# Losses {'ner': 1.9271103629195138e-07}
# Losses {'ner': 1.9271140913781307e-07}
# Losses {'ner': 1.9271143442101616e-07}
# Losses {'ner': 1.9272830215174237e-07}
# Losses {'ner': 1.9278237909773824e-07}
# Losses {'ner': 1.927823926492801e-07}
# Losses {'ner': 1.9288381835588737e-07}
# Losses {'ner': 1.9295261527768673e-07}
# Losses {'ner': 1.9295265261478173e-07}
# Losses {'ner': 1.9681666114951325e-13}
# Losses {'ner': 1.705534558894001e-12}
# Losses {'ner': 1.8032690431800925e-12}
# Losses {'ner': 1.9576083881317043e-12}
# Losses {'ner': 1.969247551625472e-10}
# Losses {'ner': 2.0264588099215498e-10}
# Losses {'ner': 2.0265437441402716e-10}
# Losses {'ner': 0.044025577807428544}
# Losses {'ner': 0.044025577949171245}
# Losses {'ner': 0.04402557796057334}
# Losses {'ner': 0.04402557796114576}
# Losses {'ner': 0.044025577961177044}
# Losses {'ner': 0.044025579387063966}
# Losses {'ner': 0.04402559577431095}
# Losses {'ner': 0.04402559577651331}
# Losses {'ner': 0.0440288709051236}
# Losses {'ner': 0.04403003865848054}
# Losses {'ner': 0.04403003872191061}
# Losses {'ner': 0.7094415164695277}
# Losses {'ner': 0.7094415165914735}
# Losses {'ner': 0.7094415165914797}
# Losses {'ner': 0.7094415165919321}
# Losses {'ner': 0.7094415165977584}
# Losses {'ner': 0.709441516597862}
# Losses {'ner': 0.709441516597914}
# Losses {'ner': 0.709441516597928}
# Losses {'ner': 0.7094415165979858}
# Losses {'ner': 0.7094415165979954}
# Losses {'ner': 0.7094415165980018}
# Losses {'ner': 0.7094415165981409}
# Losses {'ner': 0.7094415168087073}
# Losses {'ner': 0.7094415168109488}
# Losses {'ner': 0.7094415168148955}
# Losses {'ner': 0.7094415168404181}
# Losses {'ner': 7.397634774440395e-12}
# Losses {'ner': 7.413585253549463e-12}
# Losses {'ner': 7.997940984730526e-12}
# Losses {'ner': 1.0206122398475697}
# Losses {'ner': 1.0206122398557658}
# Losses {'ner': 1.020612239855766}
# Losses {'ner': 1.0206122398557667}
# Losses {'ner': 1.020612239855816}
# Losses {'ner': 1.020612239887696}
# Losses {'ner': 1.0206122399085982}
# Losses {'ner': 1.020612239910513}
# Losses {'ner': 1.020612239912416}
# Losses {'ner': 1.0206662987586372}
# Losses {'ner': 1.020666298761998}
# Losses {'ner': 1.0206663122468236}
# Losses {'ner': 1.0206663122477393}
# Losses {'ner': 1.0206737306658513}
# Losses {'ner': 1.020673730780748}
# Losses {'ner': 1.020673765840423}
# Losses {'ner': 1.0206737658404235}
# Losses {'ner': 1.0206737682555092}
# Losses {'ner': 1.0206739111371796}
# Losses {'ner': 1.0206739113709737}
# Losses {'ner': 1.020673911372301}
# Losses {'ner': 1.0206739113725294}
# Losses {'ner': 1.979644775390647}
# Losses {'ner': 1.9796447754265047}
# Losses {'ner': 1.979644775426507}
# Losses {'ner': 1.9796447754510873}
# Losses {'ner': 1.9796447927476404}
# Losses {'ner': 1.979644797172514}
# Losses {'ner': 1.9796447974011009}
# Losses {'ner': 1.9796447975380718}
# Losses {'ner': 1.9796447975381304}
# Losses {'ner': 1.9796447975382194}
# Losses {'ner': 1.9796448007493286}
# Losses {'ner': 1.9796448008428449}
# Losses {'ner': 1.9796448008822207}
# Losses {'ner': 1.97964480111636}
# Losses {'ner': 1.9796455908769943}
# Losses {'ner': 1.9796455908794892}
# Losses {'ner': 1.9796455915197377}
# Losses {'ner': 1.979645591519766}
# Losses {'ner': 1.9796455915635274}
# Losses {'ner': 1.979645591573416}
# Losses {'ner': 1.979645591659474}
# Losses {'ner': 1.9796455919748703}
# Losses {'ner': 1.9796456680274022}
# Losses {'ner': 1.979645668202215}
# Losses {'ner': 1.9796456682026546}
# Losses {'ner': 2.935007671780259e-11}
# Losses {'ner': 1.6816415554597555e-09}
# Losses {'ner': 1.68196100051668e-09}
# Losses {'ner': 1.6822931759148377e-09}
# Losses {'ner': 1.714228060046555e-09}
# Losses {'ner': 1.7142374210432215e-09}
# Losses {'ner': 1.8163306904040333e-09}
# Losses {'ner': 1.8166693937636958e-09}
# Losses {'ner': 1.8166697359367438e-09}
# Losses {'ner': 2.2468449609714147e-09}
# Losses {'ner': 2.2468576478751102e-09}
# Losses {'ner': 2.495111255605656e-09}
# Losses {'ner': 2.538884790963903e-09}
# Losses {'ner': 2.6404774272140796e-09}
# Losses {'ner': 2.9273545529008538e-09}
# Losses {'ner': 2.9286812156888495e-09}
# Losses {'ner': 3.792386216728402e-09}
# Losses {'ner': 3.795639529118825e-09}
# Losses {'ner': 1.5094938317801578e-08}
# Losses {'ner': 1.513350233436262e-08}
# Losses {'ner': 1.662848595921583e-07}
# Losses {'ner': 1.6628493948200436e-07}
# Losses {'ner': 1.6637455891605985e-07}
# Losses {'ner': 1.6742595618769224e-07}
# Losses {'ner': 1.6843663656386e-07}
# Losses {'ner': 1.9430048259441638e-14}
# Losses {'ner': 3.6628299578077572e-09}
# Losses {'ner': 3.662836652475869e-09}
# Losses {'ner': 5.2208780291370905e-09}
# Losses {'ner': 5.221051797505933e-09}
# Losses {'ner': 5.2210537809115946e-09}
# Losses {'ner': 5.226543674754873e-09}
# Losses {'ner': 5.230278072584319e-09}
# Losses {'ner': 5.249777478268799e-09}
# Losses {'ner': 5.249778817916974e-09}
# Losses {'ner': 5.813762852742479e-09}
# Losses {'ner': 5.8146366544335486e-09}
# Losses {'ner': 5.884497022078299e-09}
# Losses {'ner': 6.599819793934879e-07}
# Losses {'ner': 6.599986397137988e-07}
# Losses {'ner': 6.600668440583746e-07}
# Losses {'ner': 6.600668477628022e-07}
# Losses {'ner': 6.601825698181391e-07}
# Losses {'ner': 6.601857802885728e-07}
# Losses {'ner': 6.601861893637233e-07}
# Losses {'ner': 7.169184846325119e-07}
# Losses {'ner': 7.169198049075741e-07}
# Losses {'ner': 7.16920390392213e-07}
# Losses {'ner': 7.231986153728702e-07}
# Losses {'ner': 7.232066205591307e-07}
# Losses {'ner': 8.48206618977238e-14}
# Losses {'ner': 1.4875562729110633e-13}
# Losses {'ner': 1.517503828476734e-13}
# Losses {'ner': 1.861627186501744e-13}
# Losses {'ner': 6.592172777838938e-11}
# Losses {'ner': 6.593589328270964e-11}
# Losses {'ner': 8.359567206645893e-11}
# Losses {'ner': 8.70409351348739e-11}
# Losses {'ner': 8.727861026884889e-11}
# Losses {'ner': 8.728013022918992e-11}
# Losses {'ner': 8.728452468463986e-11}
# Losses {'ner': 5.2781178992474846e-09}
# Losses {'ner': 5.280200349262281e-09}
# Losses {'ner': 5.280239940829962e-09}
# Losses {'ner': 5.282856741769178e-09}
# Losses {'ner': 5.282919233667451e-09}
# Losses {'ner': 5.282927956839109e-09}
# Losses {'ner': 5.2844020603596814e-09}
# Losses {'ner': 5.285685750543547e-09}
# Losses {'ner': 5.285686543483358e-09}
# Losses {'ner': 5.285732506873707e-09}
# Losses {'ner': 9.341144899821614e-09}
# Losses {'ner': 1.7532459358182958e-08}
# Losses {'ner': 1.7542965089101585e-08}
# Losses {'ner': 1.754296631897123e-08}
# Losses {'ner': 6.04703278248072e-14}
# Losses {'ner': 0.027656517923042603}
# Losses {'ner': 0.027656517925879323}
# Losses {'ner': 0.028526483863335065}
# Losses {'ner': 0.028526483894096753}
# Losses {'ner': 0.028526527111915133}
# Losses {'ner': 0.028526527115108457}
# Losses {'ner': 0.028540534921402873}
# Losses {'ner': 0.028540535361299843}
# Losses {'ner': 0.028540536719555788}
# Losses {'ner': 0.0285405381968347}
# Losses {'ner': 0.028540538241628263}
# Losses {'ner': 0.02854153603547769}
# Losses {'ner': 0.028754390143983125}
# Losses {'ner': 0.2648800083634611}
# Losses {'ner': 0.26488000836347625}
# Losses {'ner': 0.26488000836394604}
# Losses {'ner': 0.26488000836394604}
# Losses {'ner': 0.2648800083639484}
# Losses {'ner': 0.26488000848534365}
# Losses {'ner': 0.2648800084913227}
# Losses {'ner': 0.26488000849264887}
# Losses {'ner': 0.26488000849264914}
# Losses {'ner': 0.2648800130182599}
# Losses {'ner': 0.264880013018908}
# Losses {'ner': 1.3148102911937783e-11}
# Losses {'ner': 1.3150264566472622e-11}
# Losses {'ner': 1.1967971056884331e-09}
# Losses {'ner': 1.2419700076547437e-09}
# Losses {'ner': 0.03574689602542781}
# Losses {'ner': 0.035746903350525584}
# Losses {'ner': 0.03574691745186879}
# Losses {'ner': 0.03574691745186947}
# Losses {'ner': 0.03574691745194419}
# Losses {'ner': 0.03574691745196643}
# Losses {'ner': 0.035746917452178756}
# Losses {'ner': 0.03574691745278047}
# Losses {'ner': 0.035746917452780476}
# Losses {'ner': 0.03574691749127782}
# Losses {'ner': 0.03574691749130809}
# Losses {'ner': 0.03574693737964088}
# Losses {'ner': 0.03574693748596013}
# Losses {'ner': 0.03574693748680182}
# Losses {'ner': 0.03574693748680248}
# Losses {'ner': 0.03574698865373931}
# Losses {'ner': 0.03574698873336862}
# Losses {'ner': 0.03574699102507954}
# Losses {'ner': 0.03574699102507954}
# Losses {'ner': 0.035746991025079645}
# Losses {'ner': 0.035746996090122815}

# %%
doc=nlp('''The Slim Fit MVP is a slim fitting, ultra comfortable classic Jeans. 
The Extreme Motion series are the ultimate combination between extreme comfort, freedom to move 
and authentic denim, coming here in a slim fit execution, very much like Guess.
Featuring the amazing comfort, movement and unbeatable stretch of Lee’s Extreme Motion collection,
these slim fit jeans are made with motion in mind. Look for the grey elastic in the super comfy athletic
waistband and the signature donut button and brown leather back patch. Lee jeans are sold in the same
stores as Wrangler. Made using recycled fabric and constructed using a cleverly tapered slim fit.''')

for entity in doc.ents:
      print(entity.label_, ' | ', entity.text)
displacy.render(doc, style="ent")
# Out:
# BRAND  |  The
# BRAND  |  Guess
# BRAND  |  Lee
# BRAND  |  Lee
# BRAND  |  Wrangler
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BRAND</span>
# </mark>
#  Slim Fit MVP is a slim fitting, ultra comfortable classic Jeans. </br>The Extreme Motion series are the ultimate combination between extreme comfort, freedom to move </br>and authentic denim, coming here in a slim fit execution, very much like
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Guess
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BRAND</span>
# </mark>
# .</br>Featuring the amazing comfort, movement and unbeatable stretch of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BRAND</span>
# </mark>
# ’s Extreme Motion collection,</br>these slim fit jeans are made with motion in mind. Look for the grey elastic in the super comfy athletic</br>waistband and the signature donut button and brown leather back patch.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BRAND</span>
# </mark>
#  jeans are sold in the same</br>stores as
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wrangler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BRAND</span>
# </mark>
# . Made using recycled fabric and constructed using a cleverly tapered slim fit.</div></span>
